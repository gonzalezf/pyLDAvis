# %%
import nltk
import time
import os

# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint
from string import digits
from string import punctuation
import unidecode

# %%
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# %%
import spacy

# %%
import Twitter_pyLDAvis as pyLDAvis
import Twitter_pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('spanish')
stop_words.extend(['linkremoved','usernameremoved','<usernameremoved>','<linkremoved>','usernameremoved_usernameremoved','linkremoved_linkremoved'])
##stop_words.extend(['from', 'subject', 're', 'edu', 'use'])

# %% [markdown]
# # Import data

# %%
ruta =  os.getcwd()+"\\data\\"

# %%
dfs = []
for file in os.listdir(ruta):
    print(f"Abriendo {file}")
    dfs.append(pd.read_csv(ruta+file,encoding='utf-8'))
print([len(x) for x in dfs])
print(sum([len(x) for x in dfs]))
df = pd.concat(dfs,ignore_index = True)
# Out:
# Abriendo Full_data_TweetsChile_normalizado_original_tweets.csv
# [123917]
# 123917

# %%
#df.columns
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
#df.Last_Name.notnull()
df.loc[df['extended_tweet.full_text'].notnull(), 'text'] = df['extended_tweet.full_text']

# %%
pd.set_option('display.max_colwidth', -1)

# %%
#borrar extended.tweet.full_text, ya no sirve
df.drop('extended_tweet.full_text',axis=1,inplace=True)

# %%
#prueba

df = df.sample(1000)

# %% [markdown]
# # Remover links

# %%
df['text'].replace({"http\\S+": '<linkremoved>'}, inplace=True, regex=True)

# %%
for texto in df['text']:
    print(texto)
# Out:
# #ChileResiste <linkremoved> con mi madre la cante gritando Adios general! espero con mis hijos cantarla gritando Adios Sebastian! #toquedequeda
# El #ToqueDeQueda hoy comienza a las 20:00 y termina a las 6:00 de mañana. Habla el Jefe Nacional de Defensa.
# @madero_cl Calcinados  ni que hijueputas En Chile están matando la gente las milicias <linkremoved>
# Plaza Ñuñoa #ChileProtests #ChileDespierta #ChileDespertoً <linkremoved>
# #Octubre el mes que cambió el país.
#
# #ChileDesperto
# Yo solo quiero un Chile 🇨🇱 justo, equitativo para todos y donde se pueda dialogar de forma civilizada y democrática #FueraPiñera #Chiledesperto #NuevaConstitucion #NomasMilicos #FueraEstadodeExcepcion
# @elmostrador Estas matando tu gente #ChileEnResistencia #pinerarenuncia #piñeraRepresor #ONUcomplice
# @24HorasTVN #ChileDesperto @24HorasTVN @canal13  y así ha pasado muchas veces los otros días, pero al llegar la represión policial, el "oponente" del pueblo se generan los disturbios. A tenido que ser el propio pueblo el encargado de defender lo que la policía y milicia no ha logrado
# En Conce, hoy nuevamente hay toque de queda, de 10 de la noche a las 6 de la mañana #toquedequeda
# Primera noticia que veo de un baleado, qué vergüenza los canales de televisión en mi país! Qué falta de ética! #ChileEnResistencia
# Si se esta cortando el Agua y el ToQue de QUEDA es el a las 19:00 y no hay nada de comercio como vamos a ir a trabajar mañana , No entiendo a protestar no mas no nos queda otra..... otra vez se estan equivocando #ChileSeCanso #CHILEDESPERTO
# Hasta los más pirulos están protestando 🤟 grande cuico 😊
# Que hombrecitos, disparando por la espalda 😡
# Con los niños no cobardes de MIERDA! #ToqueDeQuedaAhora
# Hermoso
# ¿Y el daño que le han hecho toda la clase política al legislar como las pelotas no cuenta?
# Qué asuman todos, que el problema no viene de hace una semana. Lleva demasiado tiempo.
# IMAGINEN COMO SERÁN LAS MANIFESTACIONES, CUANDO QUITEN EL #toquedequeda Y SIGAN HACIÉNDOSE LOS WEONES SIN DAR SOLUCIONES CLARAS, EL LUNES NO ESTA LEJOS! #URGENTE #ChileDespierto
# ChileDesperta
# #ChileSeCaso
# #ToqueDeQueda
# #Chile
# #NoSonSoloLos30Pesos <linkremoved>
# #chiledesperto #ChileSeCanso
#
# Colegio Farmecéutico da aviso para las ciudades: "Cualquier persona que requiera adquirir sus medicamentos urgente y no sabe qué farmacia está abierta hoy domingo, pueden escribirnos a comunicaciones@colegiofarmaceutico.cl".
# Awwwwww
# Tan buenitos ...
# 😑
# Hubo que dejar la zorra en el país para que soltaran la teta wn ohh!
# #RenunciaPiñera #ChileEnResistencia
# #ChileProtests
# Coca que?#RenunciaPiñera
# Miren @amnistiachile lo que pasa en nuestro país! Un Chile que se supone vive en democracia, los ciudadanos no pueden manifestarse porque son baleados. #Colina #ChileDesperto <linkremoved>
# @Carabdechile @Ejercito_Chile les advierto algo: sus rostros y nombres y sobretodo abusos están grabados! Cuando esto acabe caerán las demandas en su contra! #RenunciaPiñera #toquedequeda #ChileResiste #PiñeraDictador #CENSURA
# Cuando vas a perder el trabajo ya no hay golpes
# que chucha estos conchetumare que ganas de mandarles unas patás en el hocico wn, que paja la actitud de superioridad.
# Que hace este weon al lado del mentiroso de CHADWICK.
#
# #noestamosenguerra
# #autogolpe
# #YoNoEstoyEnGuerra
# #HolaChileTeInforma
# #FelizLunes #chadwick
# #ChileDesperto <linkremoved>
# Urge una asamblea constituyente  #NuevoPactoSocial #ChileDespertoً
# #toquedequeda #ChileDesperto #EstadoEmergencia el problema sr piñera, es q tiene 0 credibilidad, x ejemplo, manda ley al congreso de pensiones, sin tocarle un peso a la ganancia de las afp, con un aumento de 10 lucas en 8 años... QUE MIERDA ES ESO??!!!
# <linkremoved>
# Es una encuestita y ya la hize, a difundir ❤ ❤ ❤
# #ChileDespierta #ChileDesperto #ChileDespierto #Estadodemergencia #EstadoDeExcepcion #Chile #ChileEstaDespertando #RenunciaPiñera #RenunciaPiñeraCuliao
# Esto es Europa. Esta mierda que se mea encima de refugiados, immigrantes, ahogados, asesinados y  torturados por el sistema.
#
# #ChileDesperto
# #RenunciaPiñera
# Basta de montajes !
# Tino,  Higuita,  Trellez, incluso James nunca tendrán la grandeza de aquellos deportistas con sensibilidad social.
# @nmonckeberg renuncia mono ctm!!! #20Oct #ChileEnResistencia #ToqueDeQueda #PineraConchetumare #renuciapiñera
# Estoy hace horas mirando videos de lo que sucede en Chile, subido por usuarios, no por medios de desinformación, y la verdad que me dá pila de ansiedad y ganas de llorar, un abrazo fuerte al pueblo de Chile ✊🏻 #toquedequeda
# Una mujer resultó herida en el cuello tras disparos hechos por militares contra los manifestantes en Plaza Italia.
#
# ¿Los Derechos Humanos solo importan cuando se trata de #Venezuela?
#
# #20Oct #ChileResiste #ChileProtesta #ChileDesperto #ToqueDeQueda <linkremoved>
# @camila_vallejo @Diputados_PC Ustedes son de un nivel de inconsciencia q no tiene limite, siendo ustedes partes del problema,optan × el oportunismo político y promover a la violencia,Chile los quiere a todos fuera #ChileDesperto
# Me gustaría toparme con espina una vez que deje de ser ministro .
# El combo en el osico va , al igual que al guston culiao de Chadwick #toquedequeda
# Chile hoy necesita lograr acuerdos: no más afp: pensiones dignas, salud educación y vivienda de calidad, basta de represión
# Lo está diciendo tu hermano #JosePiñera el papurri #ChileDesperta #toquedequeda <linkremoved>
# @rialjorge Piñera dictador!
# Me dicen q para Bullrich, ya estarían actuando “células terroristas iraquíes mapuches camporistas y negros senegaleses financiados por el chavismo” en  las protestas de #Chile . Ampliaremos
# #toquedequeda #santiagochile
# A prueba de wns!!
# Milicos como francotiradores esperando en escuela militar 🤦🏽‍♂️ #EstoPasaEnChile #RenunciaPiñera #ChileDesperto
# En @canal13 #MesaCentral  @gabrielboric hizo cagar a la facha @jvanbiobio
#  #EvasionMasiva #EstadoEmergencia #ChileDesperto #EstallidoSocial #EvadirEsLuchar #toquedequeda
# Vale la pena escuchar cada minuto..!! #ChileDesperto
# #DespiertaChile #19Oct #EstadoEmergencia #ToquedeQuedaChile <linkremoved>
# En qué momento van a parar de hacer montajes? Acaso no aprendieron que SIEMPRE se sabe la verdad tras el 73'?
# #RenunciaPiñera #PiñeraDictador
# #ChileDesperto
# Las palabras de esta señora reflejan la indignación que sentimos todos  #EstoPasaEnChile #ChileDesperto <linkremoved>
# Cuidado. Lo mismo creyó Allende y la UP.
#  ¿Tan poco aprendieron?
# Donde estan los pacos que no estan protegiendo las estaciones del metro??? Ya lo sabemos cuidando los interes de la clase alta, resguardando el apumanque por wn #RenunciaPiñera #Chiledesperto #EstoPasaEnChile
# así estaba ayer en la esquina de mi casa, por eso se me rompio la cuchara de palo 😔
#  #ChileDespertoً rt<linkremoved>
# Saqueos varios en #concepcion y aún no comienza el #Estadodemergencia #EstadoEmergencia #EstadoDeExcepcion 🙄
# @Tin_76 es Cruzat el del coro?
# @LibermanOnLine @libermanmartin @davellaneda77 @LuisGasulla @noelianovillook @Late931Oficial Alguna opinión de lo que está pasando en #Chile con las marchas de #ChileDesperto y el #EstadoEmergencia
# La Cami y el Pablito Chile-e son lo mejores, van a las marchas, ayudan a la gente, quieren una cambio
#
# #ChileProtestas #PiñeraDictador #ChileSinMiedo #ChileDespierta #ChileDesperto
# “No son 30 pesos, son 30 años” @anatijoux crea un himno urgente de #Cacerolazo #Chile #ChileDespierta #ChileDesperto 💪🏻💪🏻💪🏻💪🏻 <linkremoved>
# @AlAireVTV @RALDAHIR @pedrojyajure @evoespueblo @polimonagas @CPNB_VE @NicolasMaduro @dcabellor @yelitzePSUV_ @wilfredoordazt @VTVcanal8 @DrodriguezVen @jorgerpsuv @jaarreaza @VillegasPoljak @Enny_A1306 @Barrycartaya @BCastellanoVTV @AmeliachPSUV @ANCTrabajadores @TarekWiliamSaab @ministerpublico @MaikelMorenoTSJ @TSJ_Venezuela @MichelCaballero @emmacaroagurto @JRioboVTV @luchaalmada @verochacon @jessicarengifor @mgenovez04 @ErikaOSanoja @madeleintlSUR @inafinogenova @PaoladrateleSUR @teleSURtv @ActualidadRT @ONU_es @planwac @LaHojillaenTV @WalterDossier @SoyAranguibel @MashiRafael @LulaOficial @CFKArgentina @sebastianpinera @mbachelet #CHILE #ChileDesperto #ChileProtests #ChileDespierta #ChileEnLlamas #CHILE #ChileEnResistencia YA LA SITUACIÓN EN CHILE SE LE ESCAPA DE LAS MANOS A @sebastianpinera @mbachelet #DDHH Y SE RUMORA QUE EL ALTO MANDO MILITAR DE PIÑERA LO TRAICIONA Y SE PONEN DEL LADO DEL PUEBLO
# #MesaCentral #ChileDesperto ahora y en varias partes, el agua esta fluyendo por los canales milagrosamente. Estos ladrones culiaos se están asustando, bien!!
# Cerdos culiaos @Carabdechile
# Estoy en shock!
# El caos un día cesará, y llegado el día hay que matar uno por uno a todos los carabineros que le pegaron al pueblo. No falta mucho para que vuelva la Patria Grande!
# La vocera.... #DespiertaChile #ChileNoSeRinde <linkremoved>
# @rfantuzzih Así es no todos son violentos.... #chiledespertoperotambiendeustedes #ChileDespertoً
# Cuidado gente, estan disparando a las ventanas #toquedequeda #ChileDespierta
# #ChileDesperto #ChileSeCanso esto igual es importante <linkremoved>
# Los que cuidaron supermercados,.habrán acumulado puntos para su próxima compra!🤔
#
# #ChileDesperto
# #ChalecosAmarillos
# #EstadoEmergencia
# Estos si que son saqueadores, anarcas y violentistas
# No cabe duda chadwick reptiliano de mierda
# Siguen los saqueos masivos. ¿Que falta para decretar un #ToqueDeQueda de 24 horas? @sebastianpinera @andreschadwickp @GobiernodeChile
# #ToqueDeQueda desde las 19 horas hasta las 6 am. 🤦🏽‍♂️🤦🏽‍♂️🤦🏽‍♂️🤔
# #PiñeraRenuncia o que los diputados hagan de una puta vez su pega con un #acusaciónconstitucional contra Piñera amparándose en el artículo 52 de la Constitución!
# #ChileResiste #RenunciaPiñeraCuliao #AcusacionConstitucionalPinera #ChileProtesta #ChileDespierta #ChileEnResistencia
# #toquedequeda #ChileSeCanso que rabia los weones que todavía intentan besarle el culo a los políticos. Entiendan ya que no salvan a nadie.
# Yo ya avise que mañana no voy a trabajar porque me asueto al paro
# Me sorprende como el. Gobierno minimiza los. Muertos.. Heridos a bala... Por perdigones... Los violentados injustamente y ensalza las cifras de pacos lesionados... Es increíble como se siguen burlando de la gente aún después de todo lo que pasó!!!! #EstadoEmergencia #19Oct
# Es idea mía o fue el líder quien sé coludio para cargarse a la gente? Es idea mía o el dueño de Walmart no pago impuestos al Sii? Es idea mía o fue el quien le facilitó bodegas para ser usadas como cárcel a Trump? Es para ponerse triste lo qué pasa con el Líder? #DespiertaChile
# Por esto me siento orgulloso de #Chile ! si a la expresión ciudadana pacifica! NO al #LUMPEN !!!!
# @humbertosichel
# #ChileDesperto
# #Octubre2019
# El #Chile de #PiñeraDictador
# @ChalecosAmarill @rhm1947 @YourMarkLubbers URGENTE | Militares matan a un manifestantes y lo arrastran en la calle #Chile #ChileResiste #ChileProtests #ChileSeCanso #ChileDesperto #20Oct #Estadodemergencia
# #Urgente #CarabinerosAsesinos
# <linkremoved>
# 🔴Cobertura Especial|#EstadoEmergencia
#
# En #MesaCentral comienza el #RatPack, con @andreavial, @pcomandari y @angelicabulnes. Conversamos de la reunión en La Moneda, los próximos días en el Gobierno y la búsqueda de una salida institucional a la crisis.
#
# ▶️<linkremoved> <linkremoved>
# El pueblo chileno pide que nos dejen manifestarnos SIN VIOLENCIA!
#
# #MilitaresReprimen #SINVIOLENCIA #ChileEnResistencia
# ESTAMOS EN DICTADURA #ChileDesperto #RenunciaPiñera
# Que horror! #ChileEnResistencia <linkremoved>
# Abastecimiento de confort insuficiente en el palacio la moneda se necesita urgente camiones de confort por que parece que seguirán cagando todo el día #ChileDesperto #RenunciaPiñera
# IMPORTANTE DIFUNDIR ⚠️⚠️⚠️⚠️
# #toquedequeda #EstadoEmergencia #URGENTE #ChileDespierto
# @sebastianpinera eres #PiñeraDictador te fuiste en contra de la gente
#
# #EstoPasaEnChile
# #ChadwikAsesino #ChileDespierta #ChileDesperto #Chile #EstoPasaEnChile #ChileSeCanso
# Almacenes.. compren en almacenes de barrio.. los que van quedando.. los supermercados están llenos de gente! #ChileDesperto
# No es posible que este pasando esto #ToqueQueda #pinerarenuncia #ChileDesperto <linkremoved>
# La brutalidad y cobardía de los policías/carabineros/gendarmes/prefectos, no tiene nacionalidad, se extiende por todo el planeta.
# Ver tanta violencia de uniformados a la gente me hace sentir impotencia, rabia y mucho miedo también, estoy mal pero sé que debo calmarme y meditar para mañana levantarse con más energía. GENTE SALGA A LA CALLE, vuelva antes del toque de queda pero no se ausente #ChileDesperto
# Sindicato Minera Escondida anoche votando la paralización.
# Presidente Piñera, el Paro va!
# Las y los trabajadores de Chile con el pueblo, piden el fin de la militarización y la votación urgente de un nuevo #PactoSocial
# Esto otro
# Y mientras, en el país latinoamericano “ejemplo” de economía de mercado y democracia liberal...
# Esto es @sebastianpinera Políticos y Empresarios corruptos. Esto es lo que sienten los niños de #Chile y Ustedes No ven. 😢 #ChileDesperto #ChileSeCanso Familias que no les alcanza #Regionesdespierten #chileprotest #LaTVMiente ✊🌈🔥🇨🇱
# CHILE 🇨🇱
#
# ¡SE MURIÓ EL PERRO Y QUEDÓ LA RABIA!
#
# #Chile
# #ChileProtestas
# #ChileDesperta
# #ChileDespierto
# #ChileEnMarcha
# #ChileEnResistencia
#
# @OEA_oficial @OEA_SocCivil @Almagro_OEA2015 @CIDH @ONU_es <linkremoved>
# Esto va a ser difícil de avanzar con estas y otras negativas
#
# #ChileEnCrisis
# #ChileDespertó
# #ToqueDeQueda
# LA TV MIENTE #renunciapiñera #censura #chiledesperto
# No necesitamos más víctimas durante el toque queda, regresemos a casa #Cacerolazo #abajoelgobierno  #ChileEnResistencia
# El #PactoSocial para la unidad nacional en chile, es con los #Movimientossociales, #ChileDesperto
# #NalTPP11 <linkremoved>
# Me cuesta creer q pese al descontento social el nivel d violencia y daño haya sido a gran escala! DUELE. Padres, abuelos TRISTES, nuestra Democracia vapuleada. BASTA. Quiénes propiciaron? ¿Cuál es el fin?
# #toquedequeda #ChileDespierta
# #RenunciaPiñera no queremos ladrones de presidente! #NoEstamosEnGuerra #ChileDesperto #ChileProtests #LaTVNosCensura
# #piñeractm ahi teni tu caga de #toquedequeda miles en las calles
# Esto está pasando en #Chile y no lo van a mostrar en la Tv!!
# #ChileProtests #DespiertaChile #EstadoFallido #EstadoEmergencia <linkremoved>
# CHV mostrando como que el #toquedequeda no está dando resultado.
# que se sepa!!! que los sadicos andan sueltos... 🙄 😤 😔
# #ChileDespierta #EstadoEmergencia #toquedequeda #EstadodeExepcion #EstadoDeEmergencia #ChileProtests #chilesecanso #EstoPasaEnChile #YoNoEstoyGuerra #noestamosengerra
# Ha sido una jornada bien estresante para todo Chile y para mi igual. Sin más que decir, gracias gente que hace memes. Me hacen reír y relajarme por un momento #toquedequeda <linkremoved>
# Csm #pinerarenuncia mira hasta los MILICOS sienten vergüenza de tu actuar.. Viejo de mierda
# #toquedequeda #piñeraDictador - Videos de la primera noche del toque de queda en Chile <linkremoved>
# Weon ridículo! Mas encima cuando le preguntaban "Cómo son ellos?" no se le ocurrió nada para argumentar...
# En La Serena los pacos no hicieron nada para detener a los que nos tomábamos la carretera o a los que saqueaban. Miraban de lejos. tiraron lacrimógenas en la plaza de armas, al final. Nunca los vi a pie.
# Que responden a eso @felipekast y @sebastianpinera ....Ustedes  que al momento de infundir miedo sacan a colación Araucanía ....#QueSeVayanLosMilicos #EstoPasaEnChileً #AbajoElGobierno #RenunciaPiñera #ChileDesperto
# La cancha es muy dispareja y con milicos en las calles no soluciona nada, es más profundiza su sordera Sr.Piñera. #gobiernoinoperante #escucha #toquedequeda
# " SON TODOS ".
# Unimarc de Bellavista, Valparaíso
# #Valparaíso #ToqueQueda #EstadoEmergencia <linkremoved>
# Es un deber moral de todas las figuras públicas manifestarse por lo que pasa en Chile #ChileDesperto #ChileResiste #20Oct
# El pueblo de Chile en Argentina!! Apoyo a mis hermanos en su reclamo.
#
# No se guien por lo que ven en las noticias nada mas! Desde Argentina apoyando
#
# #ChileResiste #ChileDesperto #PiñeraRenuncia <linkremoved>
# 🔴ITURRIAGA SE TUVO QUE BAJAR LOS PANTALONES | Por su dicho de esta mañana, se entendió como una suerte de disculpas aclarar dicho de que "es un hombre feliz, que el no está en guerra". Toque de queda en RM decretado a partir de las 20:00hrs. #ChileDesperto #NoHayVueltaAtrás <linkremoved>
# Estamos destruyendo nuestra casa...y nuestras vidas nuestras pensiones nuestra salud y nuestros sueldos diagnos.....mmm y era....!!#toquedequeda
# No nos sirve que solo se preocupen, hagan algo al respecto, estan matando niños en Chile!!! @UnicefChile @UNICEFenEspanol @unicef_es @UNICEFargentina @UNICEFMexico @unicefvenezuela @unicefguatemala @UNICEFuruguay @unicefpanama #toquedequeda #Chiledespierto #EstadoEmergencia <linkremoved>
# @sebastianpinera esta es tu pega #RenunciaPiñera #YoNoEstoyEnGuerra #ChileDesperto <linkremoved>
# A riesgo de sonar como un viejo culiao, espero que los mismos giles que están quemando y destruyendo todo usen la misma energía en votar por candidatos que realmente cambien el sistema. Digo, para que el #toquedequeda valga la pena #ChileDespierto #ChileResiste
# No están porque están saqueando poh!!
# Apoquindo con Manquehue, no les gustó el himno nacional a los milicos, no sin la última parte. #ChileDesperto #RenunciaPiñera #EstoPasaEnChile <linkremoved>
# Chancho qlo de Chadwick baja riéndose en La Moneda a seguir mintiendo.
# #NoEstamosEnGuerra #EstoPasaEnChile #23Oct #PiñeraDictador #ToqueDeQueda #ChileSeCanso #ChileDesperto #EstadoEmergencia #PiñeraRenuncia #RenunciaPiñera✊🏼❤️🇨🇱 <linkremoved>
# Ahorita extraño tanto mi ciudad &lt;3 puro aguante la gente del sur
# Mega qlo se creen pacos tirando agua csm
# #ChileDesperto
# #PueblosEnResistencia#ChileDesperto#FelizLunes si me sigues te sigo
# Que weon más generoso por la chucha, incluso quemándose el país entero es chuchadesumadre sigue siendo un miserable.
# Piñera debe renunciar: con que autoridad moral puede él exigirle a la gente que no robe?
# #RenunciaPiñera #ChileSeCanso #ChileDesperto
# DE QUE GUERRA?, Piñera está LOCO #CHVNoticias #Argentina #toquedequeda #ChileDesperto #ChileProtests #FelizLunes #ChileSeCanso #ToquedeQuedaChile #CooperativaToque #Chile #DDHH #ONU #FrenteAmplio #pazParaChile #ULTIMAHORA
# #Chile en una sola mirada. Una foto total del reportero gráfico Carlos V. Mansilla.
# #ChileDesperto #ChileEnMarcha #ChiledePie <linkremoved>
# La cara del 💀 JAJAJAJAJAJS
# Traidores vende patria #PiñeraDictador #EstoPasaEnChile #ChileEnResistencia #ChadwickAsesino
# Ojala la tv mostrará  en vivo el saqueo a los recursos naturales que ha sufrido este pais durante años, no el saqueo a supermercados con seguros millonarios antirrobos...
# #DespiertaChileDespierta #FuerzaChile #ChileDesperto #TVNInforma #ToqueQueda #piñera
# Karen Rojo hablando de “mi general” tras confirmar #ToqueDeQueda en #ANTOFAGASTA desde las 20:00
# Gómez Carreño #EstadoEmergencia #Chile #ChileDespierto #ChileSeCanso #ChileResiste #ChileProtesta #ToqueQueda #ChileDesperta <linkremoved>
# Discutiendo eternamente las demandas que el pueblo exige ahora. Deja de lavarte la boca con la clase media, mentirosa de mierda. Deja de hacerle felatios a Piñera weon oh  #ChileDesperto #ChileCambio #noestamosenguerra #21OCT
# "¡SOY HIJA DEL SARGENTO! ¡SOY HIJA DEL SARGENTO!"
# #ChileDespierta #ChileDesperto #Represión <linkremoved>
# Estaciónes de servicio de combustible, subieron los precios y solo están vendiendo gasolina de 97,le pregunté a los bomberos y me dijeron que eran órdenes de la compañía. Que forma de aprovechar la situación #toquedequeda
# Que vergüenza por favor 🤦
# #ChileEnResistencia #piñeradictador
# Idiotas, no es problema de izquierda   ni derecha es cumplir la constitución
#  Dime algo: la has leído alguna vez. Es obligatoria para todos los ciudadanos
# .#ToqueDeQueda
# Continua la cancelación de vuelos en varias aerolineas
# <linkremoved>
# <linkremoved>
# @sebastianpinera @sebastianpiera6 escucha tu tema. #renunciapiñera eres el peor error de Chile, eres delincuente, vándalo y extremista. @77pineda @spineram @ceciliamorel lleven al emperador a un psiquiatra #ChileDesperto #EstadoEmergencia #DDHH @CNN
# Compartir #ChileDesperto #EstoPasaEnChile
# La primera dama de Chile, Cecilia Morel, le dice a una amiga por WhatsApp que la situación en su país es casi como "una invasión alienígena". La Moneda ha reconocido que es un corte de sonido auténtico. #ChileResiste #ChileEnResistencia #ChileSeLevanta #ChileMasJusto <linkremoved>
# La Policia del Dictador Piñera golpeando menores.  #PiñeraDictador  #EstoPasaEnChile  #FuerzaChile
# Que hermoso
# #NoEstoyEnGuerraConNadie
# #PiñeraRenuncia #ChileDesperto
# El General minimizando la muerte provocada por el ejército. Sebastián Piñera ya no es un interlocutor válido del pueblo. #RenunciaPiñeraCuliao #ChileDesperto
# @Cooperativa El hombre del raspado de olla , si tuviéramos la democracia q queremos estos qlos así no estarían más en política y estarían presos como la presidenta de la udi #ChileDesperto #ChileProtests #ChileInCrisis
# Lean esto @TVN censura esto debió salir en una entrevista ayer se llama poniendo las cosas en contexto. Lean y se indignaran más #ChileDesperto #ApagaLaTele #NoEsSequiaEsSaqueo #noestamosenguerra #ChileEnResistencia #LaHistoriaImporta
# No se puede hacer una tortilla sin romper algunos huevos.🔥
#
# #ChileSeCanso #ChileProtests #ChileDespertó #toquedequeda #RenunciaPiñera
# @ApPena En un año paramos el país luego de terremotos, lo haremos de nuevo, porque eso hacemos, nos paramos.
#
# #YoApoyoAlPresidente <linkremoved>
# Amanecio triste mi ciudad... 😞#ChileResiste #Santiago #toquedequeda
# Que pasó que se detuvo el movimiento???
# #evasiontodoeldía #ChileDespertoً #renunciapineira #ToqueDeQuedaAhora #22Oct
# Ayer en Puente Alto vecinos deteniendo saqueadores en calle Clavero y quitándole lo robado y se tiraron dentro del colegio Los Aromos #MesaCentral @jvanbiobio diciendo que todos somos delincuentes ¡¡ sáquenla del programa #EstadoEmergencia
# Lo hice bien? xD
# #ChileProtests
# #ChileSeCanso
# #ToquedeQuedaChile
# #ChileDesperta
# #ChileDesperto <linkremoved>
# SERVICIO DE UTILIDAD PÚBLICA. #toquedequeda #chile #piñerarenuncia <linkremoved>
# Creo que en el mismo artículo de la constitución venezolana .
# Queridos seguidores se informa que el #toquedequeda en nuestra región comenzará a las 18:00
# Esperando que en su viaje lleguen sin novedad a sus hogares y mantener su tranquilidad y la de sus familias #quilpué #belloto #ChileDesperto #ToqueDeQuedaTotal <linkremoved>
# Cacerolazo en #viñadelmar #ChileEnResistencia #ChileDespierta arriba el pueblo chileno <linkremoved>
# Chile amanece con más esperanza en el futuro! #ChileProtesta #FinalToque #MilitaresaCuarteles #toquedequeda #ChileSeLevanta #ChileDespertó #RenunciaPiñera #ChileResiste
# <linkremoved>
# Cadena de errores del Gobierno. La oposición tampoco nada. Al final el lucrar con los sueños, aspiraciones y dignidad del pueblo dejan de ser negocio cuando se exigen de verdad. #NoEstamosEnGuerra #NoEstoyEnGuerra #ChileSeCanso #ChileDesperto
# Emocionante ... hasta las lágrimas 😢
# @elmostrador Se canso la gente de la explotación ! #ChileSeCansó  #ChileDesperto
# @JotaRpe97 Gente, vayan a trabajar tranquilos, toda la semana. #40horas y derechito para la casa. Ese será NUESTRO #toquedequeda
#
# #PiñeraRenuncia
# Ayuden a difundir
# Crees que es casualidad el ingreso de chavistas  a Chile?
#
# Crees que es casualidad que destruyan los bienes de uso público de la clase media baja?
#
# Crees que es casualidad que quieran Latinoamérica sumergida en el caos?
#
# #GrupoPuebla
# @RomiRetamal @ZurdoCruzado ¿Nos estás amenazando con un boicot económico?
#
# #ChileDesperto
# En Lo Barnechea está todo tranquilo. NO ampliaremos. #chiledespierta #toquedequeda
# #ParoNacional #EstadoDeExcepcion #ChileProtests #ChileEnResistencia #ChileDespertó #ChileCambio #ChileSeLevanta
# La claridad de Guarello 👍
# <linkremoved>
# @Carabdechile que tienen que decir al respecto? sinvergüenzas, "por falta de respeto" haber si nosotros los demandamos a ustedes por falta de respeto po
# Nunca van a recuperar la confianza del pueblo nunca @Carabdechile  @sebastianpinera @ceciliamorel  @adnradiochile  @tele13alahora #piñeradictador #piñerarenuncia #chileprotest #toquedequeda
# La mayor parte  haciendo puro show en la @CamaraDiputados Discursos vacíos tal como sus mentes.
# Esa mayoría debe estar fuera del Congreso!  #EstadoEmergencia
# Difundir. Lunes con cuidado #toquedequeda #ChileProtests #ChileSeCanso #ChileDespierta #LaTVMiente #ChileProtesta <linkremoved>
# ¿Y este otro comunista también recibe felicitaciones de Cuba?
# Si hay buses @turbuschile en el terminal de alameda, abrieron cajas en el anden 24 para comprar y las cajas que estan en el hall central del terminal son solo para cammbios, boletos sin confirmar y devoluciones #EstadoEmergencia #19Oct #19OLaMarchaDelMillon #ChileDespierta
# @vladimirpadrino @asambleapueblos
# @ResumenLatino
# @ForodeSaoPaulo
# @dquinterotv10 @soshumanidad
# @via_campesinaSP @alba_tv
# @teleSURtv @brasildefato
# @PartidoBaaz @FAI_analisis
# @PCV_Caracas @webpcpe
# @zehdeabreu @ActualidadRT
# @sirioandaluz
#
# SI BACHELET APARECE, MUÉSTRENLE ESTE VIDEO
# @JPizarroC yo con el pecho pesado por toda la situación. desde que empezó esto, lloro 3 veces al día mínimo. pero tengo fe en que #chiledesperto.
#
# fuera de mi salud mental, sano y salvo de momento.
#
# abrazo de punto válido en final de world cup, papucho.
# Pueden funar su IG! @milanignacioalarcon <linkremoved>
# #toquedequeda #EstadoEmergencia hace ya un par de dias ke no veo comentarios y tuits  de nuestro Yet set de la politica, lease; @RicardoLagos @lagosweber @mbachelet @GiorgioJackson @guidogirardi @alvaroelizalde @iallendebussi @jplchile @senadorquintana alguna opinion y/receta???
# @R1card0Est3ban_ Si, de echo, no han entrevistado nunca mas a nadie de metro desde el presidente de uno de los sindicatos q denuncio q los @Carabdechile habian habandonado el resguardo de muchas estaciones.
# @CNNChile
# @T13
# #ChileSeAburrio
# #ChileDesperto
# El día de mañana esas mamás dónde dejarán a sus hijos? 🤦🏼‍♀️ qué están esperando para cambiar el rumbo de lo que está sucediendo? #limache #toquedequeda #EstadoEmergencia #chile #urgente
# ay me tenté
# @KarlaEnAccion cuántos vagones de metro se podrían haber comprado con las contribuciones que evadió @sebastianpinera? #RenunciaPiñera #ChileDesperto #ChileSeCansó #EstadoEmergencia #Chile
# Una tía está en medio de los 2 incendios de La Pintana y no tienen agua 😱 #ToqueDeQueda
# <linkremoved> / Antes que borren los vídeos hagámoslo viral #estopasaenchile #ChileDesperto #ChileResiste #ChileProtests
# Ya nadie les cree y es por q son unos vendidos.. #LaTvMiente siempre lo ha hecho, igual q #Chadwick siempre mienten.. y ni se inmutan.#ChileDesperto #ChileResiste #ChileSeLevanta #toquedequeda #ChileSeCanso
# Mañana los matinales serán más escoria q antes,sin duda.
# No son 30 pesos, son 30 años. #ChileDesperto
# Muchos parlantes con 'el derecho de vivir en paz' en el centro ♥️ #toquedequeda
# La reunión de este mediodía es entre los mismos que provocaron esto. ¿Puede salir algo bueno de ahí?
# #Bienvenidos13 #ChileDesperto
# ¿Porqué borran estas publicaciones? ewe Eso no detendrá nada.
# #FuerzaChile #ParoNacional #pueblounidojamasseravencido #toquedequeda <linkremoved>
# @latercera Y por qué en Puente Alto saquearon todos los supermercados y no apareció ni un Carabinero o militar? @ceciperez1 @germancodina @mpuentealto #ChileDesperto
# Urgente Cecilia Moreo tenía razón!!! #renunciapiñeractm #ChadwickCTM @RNchile @udipopular #ChileDesperto #ChileEnResistencia <linkremoved>
# No te veo metiéndote con Rafael Ramírez que es el verdadero culpable de eso... Usted le jalaba bolas camaradas
# #toquedequeda
# Alguien Conoce a este HDP robo un perro que estaba internado para esterilizar favor difusión MÁXIMA!
# nada que decir todo es evidente las FFAA permiten los saqueos y punto @meganoticiascl  @CNNChile  @chilevision #ChileDesperto #ChileProtests @ActualidadRT <linkremoved>
# Lo que no muestran los medios!! #ChileDesperto #ChileQuierePaz #CHILESECANSÓ
# Milagrosamente apareció caudal de #ríoAconcagua y en otras zonas. Murieron #animales y #suicidiocriancero. Tb soltaron agua en otros pueblos por "miedo". Y en la tv nada @24HorasTVN @AndreaAristegui @CNNChile @CHVNoticitas_cl @alvarez_monse @tv_monica  @gonzaloramirex #RoboDeAgua
# Salvo lo de reunirse con los presidentes de partidos mañana, NO DIJO NADA CONCRETO DE NUEVO. BASTA! #ChileDesperto #EstoPasaEnChile
# 🔴Cobertura Especial | #EstadoEmergencia
#
# Gerente General Metro de Santiago: "Ninguna posibilidad de extender el horario. En caso de toque de queda, se adelanta el cierre".
#
# ▶️<linkremoved> <linkremoved>
# Me fui de chile hace casi un año, con ninguna intención de volver... pero hoy me hubiera gustado estar ahi.
# RENUNCIA DICTADOR!!!!
# #RenunciaPiñera
# #EstoPasaEnChile #noestamosenguerra #HabraConsecuencias #ChileDesperto
# Así que @Cadem_cl ya sacó una encuesta culiá trucha diciendo que la gente apoya el #EstadoEmergencia ???, Son tan obvios y tan ahueonaos que da risa.
# PORQUE NOSOTRAS PERDIMOS EL MIEDO.
# No somos ni de izquierda ni derecha, somos los de abajo y vamos a por los de arriba.
#   #chiledesperto #EstoPasaEnChile #pueblounido #chile #Laprensamiente #renunciapiñera
# La recomendada del día
# Querés derecha para dar orden al país y vivir sin miedo ? ... Bue anda llevando esto ...
# lo unico que me preocupa en este momento es la salud de mis abuelos y estar con ellos
# En la Pincoya no te queremos Piñera qlo
# #RenunciaPiñera
# #ChileDesperto
# #pinerarenunica <linkremoved>
# KIEEEEH XDDDDD
# En cual multiverso estamos???
# #ChileDesperto
# Puro aguante
# Con las palabras de Espina solo queda claro que este gob no nos escucha y qe lo único qe haran será intentar acallarnos aún con nuestra muerte.
#  NO LOS DEJEMOS
#
# #toquedequeda #ChileDespierta
# Osorno ya despertó #ApagaLaTele  #ChileDesperto <linkremoved>
# Un pueblo que no se deja reprimir, es de admirar #ChileDesperto #chileprotest #FuerzaChile 🇨🇱💪🏽 <linkremoved>
# La izquierda organizó este desorden y debe ser a partir de ahora declaramos a la izquierda enemigo público #YoApoyoAlPresidente
# Sigue sin entender nada. Puro metiendo miedo.
# @sebastianpinera que bueno que lo sepas, a ver si te acercas a escuchar bien al pueblo #PiñeraRenuncia #toquedequeda #Chile #RenunciaChadwick #RenunciaPiñeraCuliao <linkremoved>
# Para que luego no anden llorando ... #toquedequeda <linkremoved>
# MATEN A PIÑERA. MATEN A CHADWICK. MÁTENLOS. EJECUCIÓN PÚBLICA.
#
# ESTO ES UNA DICTADURA. QUEREMOS JUSTICIA YA. @inddhh
# #ChileDesperto #ChileResiste #toquedequeda
# Sé que nunca te rezo pero Diosito porfis, que cuando despierte por la mañana todo haya sido broma, que @sebastianpinera no sea Presi y que los pacos/milicos sean personas y no bestias. Amén. #EstadoEmergencia #ChileDespierta #ToqueDeQuedaEnChile
# Milicos son una vergüenza #toquedequeda #Chile #ChileProtests #ChileDespertó
# Estado de emergencia en #LaSerena y Coquimbo. Sumado a #Concepcion, #Valparaiso y #Santiago.
# El presidente y sus ministros ineptos desaparecidos desde ayer y militares en las calles golpeando.
# Volvimos al 73...🤦🏻‍♀️
# #ChileDesperto #toquedequeda #EstadoEmergencia #FelizDomingo
# Nunca pensé en tener que hacer fila para ingresar al súper y sobre todo ver a mi país así!!! Que te hicieron mi Chile? Tristeza y dolor... #Chile #ChileDesperto #RecuperemosChile
# #RenunciaPiñera te quedó grande !! #ChileDesperto
# #AquiFaltaPinochet  El Pueblo quiere orden y eso solo lo dan nuestros militares. #FueraBoric <linkremoved>
# Otra más que no entiende nada. Chingue su madre.
# Por dios que!!????
# @sebastianpinera los niños que hoy golpeas, mañana te van a colgar de una plaza, malparido.
# Puedes reclamar y protestar, es válido,  pero las ambulancias y sobre todo a los bomberos se les respeta...
# @heylobezno @espineraculiao PD: para difundir en tumblr
# <linkremoved>
# le llaman paz al pueblo callado y sumiso #toquedequeda #ChileDesperto
# #PineraDebeRenunciar #toquedequeda #ChileSeCanso
# Amigos ya no aguanto toda esta situacion quiero salir a protestar a hacer algo util por el pueblo pero lo que me impide es el miedo de mis padres,alguna recomendacion
# Vean y compartan maestro
#
# 👏👏👏👏👏👏
#
#  #ChileEnMarcha
#  #ChileDesperto
# #ChileSeAburrio
# #RenunciaPiñera <linkremoved>
# #Chile, si Gob. no procede a un desescalamiento del uso de la fuerza, si no retira ejercito de las calles, no habrá condiciones para dialogo político. @sebastianpinera debe hacer un paso que conduzca al dialogo. Para un conflicto político una negociación política. #CHILEDESPERTO
# #toquedequeda Con mas milicos y amenazando con el uso de armas, menos paz van a tener po, aweonao de mierda!!! La gente merece paz para llegar a fin de mes 💪💪💪😒😒😒😒
# Verificar cuentas, orientales fomentan el odio para después represión, verificar procedencia de las cuentas y antigüedad.
# #toquedequeda <linkremoved>
# Esta la caga, muere gente ahora ayer y siempre, opacan al pueblo! Liberen weon! El poder es de nosotros siempre estoy weones creen que se la pueden pero no, el pueblo se la puede y al fin nos dimos cuenta CTM!!!!
# #ChileDesperto #EstadoEmergencia #ChileDespierta #19Oct
# Pongan un #ToqueDeQueda único para todo chile! Están haciendo el loco mal en el gobierno y esta inoperancia puede costar vidas. Aumentan la confusión. 🤦🏻‍♂️
# ¿Está es tu democracia? @sebastianpinera pacíficamente un ciudadano protestaba y más de tres militares se abalanzaron contra él. ¿Esta es tu guerra? ¡Tenemos ollas! Ustedes tienen chalecos antibalas y escopetas.
# #ChileDesperto #ChileSeAburrio #FuerzaChile <linkremoved>
# @T13 Por la desidia de estos csm del gobierno que comían pizza mientras había que tomar decisiones vemos milicos en la calle! La derecha acabando cuando habla este patas hediondas!
# #ChileDesperto #toquedequeda #EstadoEmergencia
# #RenunciaPiñeraCuliao
# #Valparaiso
# Ahora al @Mega le pica el hoyo
# Cuántos políticos haciendo fila para comprar ?
#
# #ChileSeCanso
# #ChileDesperto
# @GobiernodeChile
# Y tienen la con..... de decir que los peruanos somos gente fea! 🙅🏼‍♀️
# Faltan 3’ para q se inicie el #ToquedeQueda y están gritando “el q no salta es #Paco” en 3’ no se van Nica a la casa... es sin llorar la wea, les gusta desafiar wn! 🤦🏻‍♀️🤦🏻‍♀️
# ya empezamos otra ves con el maldito toque de queda 🤬 que rabia que estamos pasando con esta tormenta viendo como los carabineros y los militares estan matando o pegando a las personas inocentes que solo estan reclamando sus derechos #ChileSeCanso #ChileDesperto 😭😭😭😭 <linkremoved>
# Esta noche de Sábado en #Chile
# Los disturbios se han extendido a otras ciudades
# Están quemando y destruyendo escuelas y edificios
# Mas 85 supermercados vandalizados y saqueados, pero casualmente NO comida: igual que alguna vez vimos aquí, Smart TV y electrodomésticos !
# Todo armado
# @Cooperativa @ElQuintoPoder #ChileDesperto #noestamosenguerra #EstoPasaEnChile Milicos defendiendo al Chile del 1%
# <linkremoved>
# Y qué quieren??? Destruir Chile??? Esa es la solución??
# #ToquedeQueda
# @nmonckeberg se lavo la cara, aun tiene la almohada pegada en la cara el wea #ChileProtesta #19Oct #toquedequeda
# Gracias Anita,xq tampoco hay q olvidar la impunidad con el pueblo mapuche. Todo lo q ha hecho este gobierno ha sido destruir a la sociedad chilena y su pueblo ancestral. Ándate Piñera, y llévate a tus primos, a los apitutados y losfascistas inoperantes q tienes en La Moneda!
# Y la destruccion entre 11 sep 73 y 1988????
# El fútbol queda en el pasado.
# Todo mis respetos a Gary Medel.
#
# <linkremoved>
# Estocolmo está con Chile!
# #chilenosensuecia #ChileDesperto #ChileProtests #piñerarenuncia <linkremoved>
# Tienen que dar una solución rápida. Porque esto ya no para hasta que se tomen medidas serias y definitivas #Protestaschile #ChileProtestas #ToqueDeQueda #desmanes #saqueos #chile
# Veo a la presidenta de la @udipopular hablando y queda claro como la derecha vive en otro mundo, un mundo penca por lo demás. #FuerzaChile #toquedequeda #MesaCentral
# Eres el mejor Gary!!!
# ESTO es lo que ha ocurrido y está ocurriendo en mi país. Pena absoluta.
# La gente de las condes está protestando porque otsea! Se quedaron sin mall, sin el after office! Jaja broma 🙃 #TodosUnidos #chile #PueblosEnResistencia #ChileDesperto #ToqueDeQuedaTotal
# Ahora les da por decir: cuantos hospitales, cuántas viviendas sociales podríamos haber construido con la plata @KarlaEnAccion te pregunto porque esperaron 2 años para construir dichas cosas? MENTIROSA! manipulando a la gente  como siempre #ChileDesperto #21Oct #EstoPasaEnChile
# que lamentable, pero esto es claramente un montaje de carabineros.... y ademas los empresarios cobran los seguros que les siguen llenando los bolsillos 🤨
# Cuando Pinochet en plena dictadura decía que “estamos en una guerra” <linkremoved> #ChileSeDefiende #ChileSeAburrió #EstadoEmergencia #21Oct
# El vandalismo lo hacen tus propios @Carabdechile no viste el Tottus que quemaron? no viste la caseta que quemaron?.. @andreschadwickp @sebastianpinera 🤡 #ChileDesperto #RenunciaPiñera #RenunciaChadwick
# por dios, como mierda vamos a querer eso,
# Las vecinas y vecinos de Recoleta cantamos #ChileDesperto 🙌🏻✊🏻 <linkremoved>
# Y si todos los rodeamos hasta que hagan la pega? Grande @pinigol51  #FelizMartes #ChileDesperto #QueSevallanLosMilicos
# @KarolCariola @sebastianpinera #pazParaChile #toquedequeda #MaduroAmenazaInternacional
# #fuerapartidocomunista #fueramadurodeChile Por Esto dijo Guerra El Presidente
#  <linkremoved>
#  <linkremoved>
# #Pacosculiaos
# Deberia darles verguenza, de verdad son los cafiches del estado! 🤬😡
# #ChileDesperto
# #EstadoEmergencia
# #toquedequeda #Chile
# Momentos clevers. Así debe ser
# A esta altura casi todo chile puede irse temprano
# #PiñeraDictador
# Escúchenlo! #ChileDesperto <linkremoved>
# Andate al toque y no se te ocurra andar pintado de payaso.
#
# Los pacos son tan weones que van a creer que eres el #Joker
# #ChileDesperto
# Vamos @DiputadosChile y @Senado_Chile den una señal concreta de compromiso social con el movimiento y #BajenseElSueldo
# Ahora es el momento @gabrielboric @GiorgioJackson @Raul_Soto1 @guillier @mjossandon @KarolCariola @camila_vallejo @mariseka
# #ChileDesperto #ChileDespierta
# Es una no he eterna, sentir las sirenas constantemente, tener miedo de que puedan atentar contra tus conocidos/seres queridos, miedo de que ocurra lo peor contra el #pueblo quien verdaderamente es el alma y esencia de este país
# #toquedequeda #Chile  #ChileDespierta
# 4/4 El gigante de poleron soy yo, el de rojo es @nancybo86093649 y @jaimecidfgh sapeaba a los pacos piola de cerca por si se ponían brigidos. #ChileDesperto
# 19:40🔴Declaran #ToquedeQueda en comuna de #Antofagasta. Comienza a las 21 hrs del día de hoy y finaliza a las 06 hrs del día lunes 21 de octubre
# @Senado_Chile @CamaraDiputados tomen nota...
# ESTAMOS EN VIVO TRANSMITIENDO A TRAVÉS DE INSTAGRAM TODO LO QUE ESTÁ PASANDO EN PLAZA ITALIA  #ChileDesperto
# Que chucha da soluciones da soluciones concretas wn y así quieres que nos bajemos #EstoPasaEnChile #ChileDesperto
# Corre ctm #RenunciaPineraCuliao <linkremoved>
# Los Ciudadanos Honestos y Esforzados, el verdadero motor de chile, necesitamos de ustedes para poner fin a esta viiolencia injustificada y a todos los saqueos que amenazan a nuestros compatriotas, familias y hogares
# El estado que a veces es neoliberal u otras paternalista no podría oponerse. Un Parlamento Virtual es posible, no sólo posible es el futuro. Es un nuevo pacto Social #ChileProtests #ChileEnCrisis #ChileDesperto #ChileSeCanso #Chile
# El pueblo, el pueblo, el pueblo donde está? El pueblo ESTÁ EN LA CALLE EXIGIENDO DIGNIDAD!!! #pineirarenuncia #ChileDesperto #21Oct #ChileSinMiedo <linkremoved>
# Supimos salir a comprar marihuana a la 1 de la mañana en #toquedequeda 🤘🏼👊🏼
# No queremos orden y seguridad, queremos llegar dignamente a fin de mes #CHILEDESPERTO
# Como paramos esto? Sigan haciendo su vida normal dentro de lo q puedan!!! Ya se entendio la idea y de sobremanera #chiledesperto #toquedequeda #24HorasCentral #T13Central
# Hey @CHVNoticias @24HorasTVN @T13 @meganoticiascl ¿Dónde está el 4to Poder? Callar los hace cómplices. #toquedequeda #ChileDespertó #Chile
# Hay muchas pruebas...
# Ojalá el estado me costee una buena terapia de psiquiatría porque realmente estoy teniendo demasiadas crisis de ansiedad y me da pánico pensar en abandonar mi hogar o salir de casa. Mi salud mental se ve enormemente deteriorada.
# #toquedequeda
# Enfermos #chile #bomberos #toquedequeda #ChileDesperto #EstadoDeEmergencia #EstadoDeExcepcion
# #ChileSeCanso Aquí están los guaripolas del ganado adoctrinado que anda haciendo caos a propósito. NO OLVIDAR.
# Será ese el verdadero problema?
# Ay chilenos al igual que  los ecuatorianos, argentinos, venezolanos, colombianos, nos acostumbraron a Subsidios Indirectos y Modelo de Renta.
# En Vzla se soluciona así
# #Lista #bolivarEnLaBlockchain, en esos paises también
# EXÍJANLO A SUS GOBIERNOS <linkremoved>
# Todavía algunos no conectan con la realidad del país.
# “Nuestro deber es deter a quienes han cometido delitos”
# ¿Y todos esos milicos que se metieron a casas o apuntaron con sus armas a gente inocente?
# #ChileDesperto
# Entendió la wea. Aguante los profesionales de la salud que luchan 👏🏼
# Aah, este Interista si se puede ver 😍
# Propongo protesta pacifica en Sanhattan
# A ver cómo se cagarían los dueños de la alcancía?
#
# #RenunciaPiñera
# #PiñeraCuliao
# #PiñeraDictador
# #ChileEnResistencia <linkremoved>
# Piñera Esta no la EVADES!
# ❤️
# #ChileDesperto #NoMasAbusos #RenunciaPiñera #EstoPasaEnChile #FuerzaChile #NOaLaViolencia #YoNOEstoyenGuerra
# Siempre las mismas promesas, ni para las crisis sabes lo que el pueblo con todos sus gritos desea y clama... Las palabras vacías te las puedes llevar con tu saquito de corruptos, porque #chiledesperto #renunciapiñera
# Sra @mbachelet existen personas despreciables, pero una mujer abyecta como usted, pocas, su ápice de conciencia yace sobre pilas de crímenes horrendos contra la humanidad, habló sobre dizque "expectativas", pamplinas! su gestión es un insulto a la filantropía...
# Y eso que se supone que Chile es el país más desarrollado, civilizado y controlado de América Latina!! Bien por el pueblo chileno #ChileDesperto 🇨🇱 Abrazos desde México y que pronto se recupere la paz.
# #GeneralIturriaga no nos gusta cumplir este rol... Por años hicieron desaparecer a la gente que pensaba distinto, y ahora vienen con esto 🤣 #FuerzaChile #ChileDesperto
# Pacos culiaos!!!
# ASÍ SE HABLA!
# #NoSeTrataDePartidosPoliticos
# #ChileDesperto
# #ChileEnToqueDeQueda
# FUERZA DE CARABINEROS DE CHILE ROBANDO, URGENTE MUNDO #España #EEUU #LatinoAmerica #CHVNoticias #Venezuela #Argentina #Peru #Mexico #Alemania #France #toquedequeda #ChileDesperto #ChileProtests #FelizDomingo #ChileSeCanso #ToquedeQuedaChile #CooperativaToque #Chile #DDHH #ONU
# #ChilenesAutoconvocades frente al consulado chileno en la ciudad de Buenos Aires 👇
# #ChileEnResistencia <linkremoved>
# Hay Dios mio 🤦‍♀️🤦‍♀️🤦‍♀️#EstoPasaEnChile #ChileDesperto #EstadoDeEmergencia #DespiertaChile #toquedequeda
# #EstoPasaEnChile 🇨🇱
# #ChileDesperto, el grito de miles de estudiantes chilenos en una nueva jornada de movilización
# Lee más 》》 <linkremoved> <linkremoved>
# @IgnacioAchurra Esto es terrible, es #AtentadoALaDemocracia declarar #EstadodeExcepcion #EstadoDeEmergencia y decretar #toquedequeda.
# #ParaQueNuncaMasChile quedó como eslogan cliché para este gobierno q usa las mismas estrategias represivas q en dictadura.
# #NoMas el pueblo no nos merecemos esto.
# Las blancas palomas.
# Esto es obra de la Internacional Socialista y sus secuaces.
# ¿Se les fue la mano? Miren lo que hicieron de Venezuela
# Chilenos, en especial usted @sebastianpinera, recuerden que en la jungla no se caza con gomeras.
# Y los tibios no hacen historia.
# Nada, sólo eso.
# #EstadoEmergencia
# #toquedequeda
# #Chile
# EL PUEBLO DEBE ESTAR CON Y PARA EL PUEBLO! ✊🏼 #toquedequeda #ChileDesperto <linkremoved>
# Así las cosas la represión del sátrapa @sebastianpinera contra de los chilenos y todo por su ambición y la del FMI.
# ARRIBA CHILENAS Y CHILENOS... ABAJO PIÑERA DICTADOR . REPUDIO AL GOBIERNO  #RenunciaPiñera #ChileDesperto #chile #plazaitalia #CHILESECANSÓ #ChadwikAsesino  #piñeradictador  #EstoPasaEnChile #QueSeVayanLosMilicos
# ¿Filantropía? No, señor. Chile necesita equidad, justicia y dignidad.
# PIÑERA
# ¿¿CUAL ES EL RESULTADO DE LA REUNION CON LOS PARTIDOS POLITICOS DE IZQUIERDA FALSA Y DE CENTRO VENDIDOS??
#
# @GobiernodeChile
#  @24HorasTVN
#  @CNNChile
#  @CIDH
#  @ONU_derechos
#  #ChileCambio #ChileEnResistencia #QueSevallanLosMilicos #AbajoElGOBIERNO <linkremoved>
# #ChileDesperto Grande el interprete de señas en #Mega,haciendo el ruido de #Cacerolazos...es #ElPuebloUnido q #NoEstamosSolos ni en #TiemposdeGuerra...#ChileProtests #PrayforChile #ChileDespierta #RenunciaPiñera #QueseVayanTodos <linkremoved>
# Sin palabras
# Lo siento mucho porque hay personas que perdieron sus trabajos, su sustento de vida con sus negocios quemados y destruido.
# Eso no es manifestarse, es maldad a su pinto máximo
# #toquedequeda #FuerzaChile
# #ChileSeCanso
# @CamilaPazAU @stateofdaylight No me matan a nadie, los míos estan bien cuidados en casa, y tienes razon los carabineros no siempre llegan cuando los llamas, pero tampoco son el mal encarnado #Urgente #toquedequeda
# Concha Tu Madre
#
# @sebastianpinera
#
# #Chile
# #chileprotest
# #ChileBajoAtaque
# #ChileEnLlamas
# #ChileEnResistencia
# Esta es la dictadura disfrazada de democracia que Chile está viviendo por culpa del pusilánime bueno para nada del presidente Sebastián piñera.
#
# #toquedequeda
# #EstadoEmergencia
# <linkremoved>
# ¿por qué debería haber cultura de toque de queda en un país que ya pasó por dictadura, en un país con supuesta democracia?
#
# dime, ¿por qué nuestros niños debería saber que ya no pueden salir a jugar en las tardes porque los milicos los pueden matar?
# #DespiertaChile
# #ChileDesperto hermoso.
# #EstoPasaEnChile
# SI resistimos lo suficiente los pacos y milicos se van a morir de sobredosis.....
# #ChileEnResistencia #bienvenido13 #EstadoDeExcepcion #ToqueQueda
# @T13 Va seguir hablando de robos y saqueos, y las demandas sociales nada, 2 veces le preguntaron. #ChileDespertoً   #chiledespierta
# Hay Historia porque hay feroz Memoria!
# #ChileDesperto
# #NoEstamosEnGuerra
# #PiñeraRenuncia  <linkremoved>
# @andrs_jaime @PamJiles Eshtupida, shile quieresh trabajash y... aweonao!!! Anda a protestar mejor!!! mira que tanto pico en el ojo ya ni vez la realidad #ChileDesperto #RenunciaPiñera
# Paren los montajes po loco... ojalá que alguna cadena de televisión muestren esta obra teatral😤 ⁦⁦@chilevision⁩ ⁦@meganoticiascl⁩ ⁦@24HorasTVN⁩ ⁦@canal13⁩ vamos saquen este video y muéstrenlo... #ChileDesperto DIFUNDIR <linkremoved>
# #Bienvenidos #EstoPasaEnChile #NoEstamosEnGuerra #YoNoEstoyEnGuerra #LaTVMiente #210ct #gobiernodechilementiroso #chilesecanso #chileresiste #chileenresistencia
# #RebajaDietaParlamentaria #HabraConsecuencias que fuerte las palabras de los alcaldes
# @sebastianpinera @ValdebenitoNata @ONU_es @unicef_es @ocdeenespanol @AngelaMerkelSPD @jacindaardern @ricky_martin @monlaferte @AlejandroSanz @juanes
# No lo inventamos en Chile, no nos aislaron, tenemos gente en el mundo apoyando
# @MarcoRamosCruz1 @bevirage @Espantobreve @tritigrehernan @JulioOrellana @marenos24175207 @ugamig1 @sinpelos2010 @Jhonnyaramayo1 @jptipnis @PabloArceVieira @Ruth977254491 @za_pito @Shei_sm7 @NoFear21F @AlbertoRealname @locota9 @Favi23573751 @vanchi_tavera @Christi70682101 @Daniel77799727 @Gaelito08594974 @JohnnyBamb @Denniss93214338 @ElvinAngelLina3 @PrincipeEber @lagentedellago @Carito13440640 @Alejand07215192 @csoria_eid @lobonoche @PabloEid @bitduart @Chari61439076 @mendezdecadario @llamerosolo @SResista @aeoblitaspaz @ciudadan0libre @jaredxbcx @vj007tr @renepereiras @Virgili99138815 @fredarpo @therinsomnia @dindi888 @CAZADORDECORRU4 @johnramos28 @DitoZambrana @evoespueblo La historia se repite... El protagonista, es el mismo. #toquedequeda #EstadoDeEmergencia #19Oct #ChileDespierta #FuerzaChile <linkremoved>
# Y por eso mismo la forma más efectiva para sacar a Piñera y todo su gabinete que NO ENTIENDEN NADA es #HuelgaGeneral  Indefinida YA
# NO llega al viernes.Los mismos que financiaron su campaña lo sacan
# EL MODELO NEOLIBERAL DEBE TERMINAR
# #RenunciaPinera
# #AsambleaConstituyenteAhora
# ...
# ¡¡Cómo cuándo no quieres responder!! #QueSeVayanLosMilicos  #EstoPasaEnChile #ChileProtesta #ChileDesperto <linkremoved>
# Piñera describiéndose o anticipándose: “como puede un presidente ser insensible para reprimir a su pueblo” #ChileDesperto vía @xennxiety <linkremoved>
# Una imagen.... Que muestra realmente quienes tienen el poder adquisitivo en nuestra sociedad #ChileDesperto #toquedequeda #FuerzaChile #ChileProtests #ChileQuierePaz <linkremoved>
# 😢 Que horror!
# Me sorprende que el limítrofe de Piñera aún no se equivoque en decirle "Iturrieta" a Iturriaga.
# #RenunciaPiñera #PueblosEnResistencia #chileenresistencia
# #toquedequeda
# ¿Qué mierda tienen que andar haciendo en las calles durante el toque de queda? ¿Por qué la gente se expone a tanto riesgo?
# Lo peor que pueden hacer es desafiar a las fuerzas armadas. Lo que más necesitamos es paz y que nuestro país recupere el orden
# Lucha de pueblo contra pueblo inspirada por PIÑEDO. A él no le interesa la vida de su pueblo, merece el peor de los castigos. Es una lacra insensible y pscicópata que ni siquiera respeta a los niños. Al ejército les pido, que bajen sus armas y se unan a sus hermanos chilenos
# MUESTREN ESTO EN LA TELE @meganoticiascl @T13 @CNNChile  ESTO ES CHILE #EstoPasaEnChileً 🇨🇱
# Me reportan en este momento que en #SantiagoDeChile hay manifestaciones afuera de los canales de televisión. Aparentemente, los reclamos son por coberturas amañadas y desinformación general en torno al número de muertes por marchas previas. #ChileDesperto
# porque el gobierno los caga como quiere
# porque la tele y los medios mienten
# porque los fachos dicen “no es la manera”
# porque la tele no ha hecho recuento de muertos
# #EstadoEmergencia #EstadoDeExcepcion #ChileDesperto
# Todos los muertos son tu culpa @sebastianpinera , tu sacaste a los militares, tu reabriste la herida. Yo te tenia por ladrón, pero ahora también eres asesino. #EstadoEmergencia #ToqueDeQueda #ChileDespierta
# No amigo, los que protestan no son delincuentes.
# Gracias a Dios no soy ni policia ni milico, no soy un perro sabueso asesino, y puedo dormir con la conciencia tranquila 😌💤 #piñeraDictador #toqueDeQueda
# @JorgeAlis el chistoso ,, comenzo enseñando a "EVADIR EL METRO A LOS CHILENOS "  que termino con mas de 41 estaciones destruidas ,,,AHORA ESTA ESCONDIDO Y SE HACE EL WEON ya te pasaremos la cuenta Argentino culiao #ToqueDeQueda
# Me imagino que la loquita del “weona tu podi” va sacar la taza de “Renuncia Piñera” y va a cobrar 20lks por la tazajajajajajajaja #piñerarenuncia #toquedequeda #chiledesperto
# Yo soy de las escépticas realmente habrán 3 persona muertas,  no se me tirén en encima, yo no le creo nada a este gobierno y a ningún político en realidad, así que me parece bastante conveniente 3 muertos solo digo  #toquedequeda
# @CNNChile Que podemos aprender de esta protesta, es que el @GobiernodeChile de @sebastianpinera son expertos en combatir el #fuego con #bencina y pronto veremos a @andreschadwickp y @albertoespina usar el extintor como propulsor #ChileDesperto #toquedequeda #FuerzaChile #RenunciaChadwick <linkremoved>
# ¡Se va con todo! #ChileDespierta #ChileDesperto #ChileProtests @Conciencia_Fem <linkremoved>
# Preocupante.. llevan contadas conferencias de prensa y todas sin un discurso sólido, pidiendole a la ciudadanía ayuda... un gran fail comunicacional !! #EstadoEmergencia #toquedequeda #DespiertaChile #19Oct #20Oct #
# Que linda idea en medio de tanto caos. #ElDerechoDeVivirEnPaz #VíctorJara #Cacerolazo #ToquedeQueda
# El único canal que es más cuerdo con lo que habla y dice verdades como puño es @LaRedTV . El único canal que hace la pega como corresponde #ChileDesperto #ChileQuierePaz
# Difundamos !!!!!! Periodista de telesur detenido x los soldados chilenos
# Han matado a destajo y a todos les importa mas que estén saqueando un supermercado a que le estén quitando la vida a cientos de personas!!! Que rabia que impotencia su falta de empatia!! #toquedequeda #ToqueQueda #LaPrensaMiente #renunciapiñeractm <linkremoved>
# Ahora que están los milicos en la calle , no aprovechan y agarran a los Narcos , estamos en #EstadoEmergencia aprovechemos la oportunidad y sacamos a una de las lacras sociales que nos aquejan , darle a un pelusa no tiene gracia
# #FueraBoric periodista d #ahora24 elogiando a los danzantes narcotizados q están en plaza ÑuÑoa persisten en mantenerse ahí aun cuando se les advierto d la pronta entrada en vigencia del #toquedequeda en franca sedición
# dirán los journalistas, vinieron los militares a provocar?
# Lo mismo pienso. Ellos son muy caras de..... #EstadoEmergencia
# Neumáticos diseñados originalmente para movernos sin fricción, hoy son re-significados como barricadas que nos obligan a parar y resistir.
#
# #ChileDesperto <linkremoved>
# Quedara en la memoria pacos qlos y los militares cosa que no es novedad rechuchetumares , se fueron en contra el pueblo, de ese mismo donde vienes TÚ #ChileResiste #toquedequeda
# Este hilo
# La kgo la pura y santa verdad
# Acá la descubrieron .
# Es mi ídolo, neta.
# DESAPARECIDA!Amigos de chile por favor necesitamos su apoyo, la hermana de una de nuestras integrantes está desaparecida!Salió ayer a las 15:00 a Puente Alto en la micro F03, +56954236353!!! #estadoemergencia #chiledesperto #chile #toquedequeda @monlaferte
# POR FAVOR DIFUNDIR <linkremoved>
# #despiertachile lo que está pasando es maquinado desde afuera @joseantoniokast @tere_marinovic #FueraComunismoDeChile #FueraBoric #fuerajackson #fueravallejos #FueraFrenteAmplio #FueraSocialistas
# Todos debemos tomar conciencia. @Carabdechile también. Veo policías más jóvenes distintos del lumpen solo por el uniforme, escenificando con ganas su 73. HOY es la oportunidad para que den muestra de rectitud ética y ciudadana. Contengan el desmán. Rehúsen reprimir. Protejan.
# Si cortan Internet <linkremoved>
# #ChileDesperto #ChileResiste #Chile #ChileEnResistencia
# @subelaradio #ChileDesperto #caseritas a mi me pasa algo especial xq mi pareja es extranjera lleva 13 años aquí nunca ha vivido algo así, trato de explicarle que esto es por un bien para todos los chilenos y también para los extranjeros que viven aquí, éramos un pueblo reprimido
# Por qué todos los muertos aparecen dentro de supermercados saqueados? Cecilia Morel....🤦‍♀️🤦‍♂️Y su audio.
# #PiñeraDictador
# #ChadwickRenuncia
# #PiñeraRenuncia
# #ChadwickAsesino
# #ChileDesperto <linkremoved>
# El lunes no habrá toque de queda, cierto? Porque quién chucha llega a su casa desde el trabajo antes de las 7????
# #EstadoDeEmergencia #DespiertaChile #ChileDespierto #ChileResiste
# Así no más con el oasis de democracia de Piñera #autogolpe #ChileEnResistencia
# #ChileQuierePaz #ChileDesperto Petitorio para deponer cualquier manifestación y volver a la normalidad
# #petitorioXChile <linkremoved>
# Información sobre el uso de salvo conducto #toquedequeda #Valparaiso <linkremoved>
# | Amo a juan carlos bodoque uwu
# Alguien sabe de locales abiertos en Providencia? necesito comprar comida de gato, ayuda 😩 #toquedequeda #Providencia #ChileProtests #ChileDesperto
# ¡Alerta, Plaza Italia con el payaso!
#
# #ChileResiste #CHILESECANSÓ
# #PiñeraRenuncia #renunciachadwick #CHILEDESPERTO en Santiago, Chile <linkremoved>
# No me agrada mucho Guarello, pero hace el análisis mas acertado que he leído hasta el momento.
# No es mentira lo que dijo la Sra del TIRANO, están sobrepasados, perdieron el autocontrol, sigue la  prepotencia, y quieren seguir apagando el fuego con bencina
# #FuerzaChile
# #ChileDesperto
# #NoEstamosEnGuerraMierda
# #RenunciaChadwick
# #RenunciaPiñera
# 🔴Cobertura Especial | #ToqueDeQueda
#
# Cecilia Pérez, Vocera de Gobierno: "Esperamos que esta violencia no solo sea contenida, sino que pare"
#
# ▶️<linkremoved> <linkremoved>
# FLEXIBILIDAD PARA PERSONAL AEROPORTUARIO!! COMPAÑEROS NO PUEDEN RETORNAR A SUS HOGARES. #ChileProtests #ToquedeQuedaChile #RenunciaPiñera #EstadoEmergencia
# Vamos #EstadoEmergencia #19Oct #ChileDespierta #Concepcion #LaSerena #ChileDesperto #ChileDespierto #FuerzaChile <linkremoved>
# re en esa
# ¡Hijo de puta!
# #DondeEstaPiñera ??? Arrancando fiera de Chile #toquedequeda #ChileSeCansó
# Los europeos  del sur,,,?! El vendedor  de ilusiones..!
# Cantante Mon Laferte envió duro mensaje a Sebastián Piñera por #toquedequeda #Chile
# no es lo mismo orden público que paz social
# #ChileDesperto
# Organización territorial y a no decaer, no podemos darle la razón a un gobierno que no entiende nada #PueblosEnResistencia #ChileDespierta #ChileDesperto #toquedequeda #RenunciaPiñera
# Tienen miedo #tienenmiedo #toquedequeda
# #ChileProtests
# #abajolasafp #fueralasafp <linkremoved>
# Buena autocrtica. Payaso
# Estamos a sus ordenes, <linkremoved> , en compras mayores de $1,500 entregamos a tu domicilio gratis!!. #toquedequeda #MeMojoCuando #cumpleaños #ventaporcatalogo <linkremoved> <linkremoved>
# @DMatamala @tv_monica @matiasdelrio y macarena pizarro desde que ganan harta plata se les olvida decir las cosas como son, se aburguesaron. Pobre caballero que le pegaron los pacos, pero se hicieron los confundidos #chiledesperto
# Sebastián Piñera resucitó a Pinochet.
#
# #ChileConstituyenteYa
# "... Es el canto universal
# cadena que hará triunfar,
# el derecho de vivir en paz."
# #VíctorJara más vivo que nunca en #ChileEnResistencia
# SE ESTÁN MANCHANDO CON LA SANGRE DE LA GENTE QUE JURARON PROTEGER #CHILE #CHILEDESPERTO #ChileProtests #ChileResiste #EstadoFallido #Estadodemergencia #toquedequeda  <linkremoved>
# El pueblo Chileno honesto y trabajador prevalecerá. Después de la tomenta el Frente amplio y partido comunista deberán pagar su traición contra el pueblo Chileno!!
# #ChalecosAmarillos
# #ChileSeCanso
# #toquedequeda
# Este es el video claramente es abuso de poder, #ChileDesperto #Noestamosenguerra <linkremoved>
# #Chile Los cacerolazos y desobediencia civil masiva se replica en varias ciudades, como Concepción. Organizaciones denuncian una escasa y desvirtuada cobertura en los medios masivos.
#
# #ChileDespertó #NoEstamosEnGuerra #EstamosUnidos #ChileEnResistencia #ChileSeLevanta <linkremoved>
# Si bien es positivo que la gente al rededor de @sebastianpinera se este desmarcando de sus hueonas palabras de estar en guerra. Ya salio Iturriaga y Rubilar dando un paso al lado, pero pueden ser lobos disfrazados de oveja 👁 #RenunciaPiñera #ParoNacional #ChileDesperto
# @mbachelet yujuuuuu estás allí tienes 2 días que no envías un tweet y tú pueblo lo están moliendo a palos y tú brillas por tu ausencia, que cosas no, será que los derechos humanos en #chile son de otra forma o al estilo #Pinochet #toquedequeda #ChileProtests #EstadoDeExcepcion
# Parte 1
# Opino igual! Defender mis ideales, mis derechos y mi dignidad, no es quemar y destruir mi país!
# Lo que los medios no muestran son las marchas pacíficas!!!
# #Baquedano
# #ApagaLaTele #PueblosEnResistencia #ChileEnMarcha #MilicosSinGloria
# #TVNInforma
# #ChileDesperto
# #CooperativaContigo
# #adnradio
# #ChileDespierta <linkremoved>
# Que no estan secuestrados, estan retenidos, se les ve el rostro si reconocen a alguno vayan a buscarlo pregunten por el dando el rut, aai de sencillo. #FakeNews  #Urgente
# Ojo ahí... No se dejen manipular!
# #ChileDespierta #ChileDesperto #EvasionMasiva #DespiertaChile #EvadirEsLuchar #RenunciaPiñera #chile #21Oct #renunciapiñeractm <linkremoved>
# Primera ves q los diputados trabajan movieron el culo de sus casas y están haciendo algo por el país #toquedequeda #ChileProtesta #ChileProtests #SantiagodeChile
# @andreschadwickp RENUNCIA CONCHETUMAREEEEE!!! 😡😡😡😡 #ChileDesperto
# Montaje de noticias, montaje de incendios.
# Esta será la manera de resolver de #piñera ?
# Procesen a esta desgraciada vaga que destruye a la patria.
# Ojo medios basura: #URGENTE | La fuerza popular sigue activa en las calles de Chile. Manifestantes incendian diario El Mercurio de Valparaíso.
# #ChileResiste
# #ChileDespierta
# #toquedequeda
# #ChileProtesta <linkremoved>
# Vo' mismo ladrón culiao.
#
# #PiñeraDictador
# #ChadwickAsesino
# #AbajoElGobierno
# #NoEstamosEnGuerra
# #ChileEnResistencia
# #PiñeraRenuncia le acaba de declarar la guerra a su pueblo. Pueblo con cacerolas y cucharas de palo. #ChileSeCanso #ChileEnResistencia
# Los esencia de los pueblos sudamericanos es de liberación, respeto a los derechos humanos y lucha por la equidad social. Cada vez más el espíritu de Simón Bolívar aparece en nosotros..!!
# Presidente @sebastianpinera FFAA y Carabineros, deben contar con su respaldo total y con atribuciones claras y efectivas. El tiempo d conversar ya fue. Lo van a criticar por si o por no tiene el futuro d Chile en sus manos atine.
# Toque de queda en #talca desde las 9 en adelante , algo breve y conciso, algo tan mínimo como jugar genera felicidad en los pequeños niños inocentes ❤🙌  #Talca #ChileEnResistencia #RenunciaPiñera #felicidad <linkremoved>
# Esto esperaban los pseudo revolucionarios y después preguntan porque mandan a los milicos 🤦🏻‍♂️🤦🏻‍♂️🤦🏻‍♂️🤦🏻‍♂️ smh (y no me vengan que son los pacos y bla bla, esto fue el pueblo, robando y aprovechando cualquier cosa para actuar con violencia...) #toquedequeda #ChileDesperto <linkremoved>
# Me emocioné...#EstoPasaEnChileً #ChileDesperto
# Duro poco el #noestamosenguerra. Pidiendo perdón, le tiraron las orejas. #pinerarenuncia #ChileDesperto #EstadoDeEmergencia
# #YoApoyoAlPresidente y tambien al #toquedequeda.
# LAS PYMES PODRIAMOS CONTRIBUIR NO PAGANDO EL IVA Y NO PRESENTANDO LOS FORMULARIOS 29 #ChileSeCanso #enacional #toquedequeda #FuerzaChile #ChileDesperto
# A los balazos, cacerolazo!!
#
# #RenunciaPiñera
# #ChileDesperto
# #Noestamosenguerra
# Gary Alexis Medel Soto siempre del lado correcta de la historia
# Te quedó grande el poncho #pineirarenuncia #ChileDesperto
# Así es como la tele te miente
# #EvasionMasivaTodoElDia  #EvasionTodoElDia  #EvasionMasiva  #EvadirEsLuchar  #ChileDespierta #Chile #pacosqlios  #pineraestanolaevades  #CHILEDESPERTÓ #ChileDesperto  #EstadoEmergencia  #toquedequeda <linkremoved>
# Un solo gesto. ¿Tan complicado es?
# #toquedequeda
# #20Oct
# #FelizDomingo
# #FelizFinSemana <linkremoved>
# #ChileResiste no me sorprende que el gobierno criminal permita que los militares y pacos asesinen al pueblo, todos ellos desde Piñera, Chadwick, espina, ect admiraban hasta los huesos al asesino pinochet y su régimen del terror. #toquedequeda
# OJO! Canal 13 está haciendo pasar como "Último Minuto" material de un saqueo que ocurrió hace horas. Se les pasó sacar la pestaña que señala "hace instantes". HAY QUE DENUNCIAR AL CNTV. Están mintiendo descaradamente. #TvMiente #ChileDesperto #19Oct <linkremoved>
# Nuevamente los militares disparan al pueblo! #RenunciaPiñera! Asesino y cobarde, escondido en su guarida... #LasCondes #ChileDesperto <linkremoved>
# Renuncia Teillier!
# Aprovechando..
# #ChileDesperto #ChileEnResistencia #ChileQuierePaz #ChileEnMarcha <linkremoved>
# El estado chileno permite alzas de precios que son impresentables. En todo orden de cosas. La culpa es de todos los gobiernos anteriores, que con su cara de raja y llenarse los bolsillos propios. Hicieron de Chile esto, consecuencia de la inoperancia de sus labores. #toquedequeda
# Es chistoso ver a la clase política tratando de empatizar con el malestar social, pero se nota mucho que su verdadero interés es solo que pase la “emergencia” para volver al status quo #ChileDesperto
# #/PiñeraEstoyContigo para levantarte a patas en la raja luego de k firmes tu renuncia, sapo reculiao
# Enserio leer ese hastag es pa cagarse de risa 😂👌pero no RT por k los apollan!!!
# #PiñeraDictador
# #ChileResiste
# #Estadodemergencia
# #EstadodeExepcion
# #toquedequeda
# "¿Cómo Chile saldrá de esto?" en vez de "¿Cómo Sebastián saldrá de esto?"
#
# Grande @cesifoti.
# Manifestantes de #Coquimbo en camino a #LaSerena #Chiledesperto <linkremoved>
# Lean esto
# "Hay una razón por la que separas el ejercito de la policía. Uno lucha contra los enemigos del estado, el otro sirve y protege a la gente. Cuando el ejercito es ambos, el enemigo del estado es la gente." #DespiertaChile #YoNoEstoyEnGuerra #RenunciaPiñera
# Los discursos de Chadwick y Espina... dejan mucho que desear... sólo culpan y no se responsabilizan de años de arrastre... #ChileEnMarcha #ChileDesperto

# %% [markdown]
# # remove usernames

# %%
df['text'].replace({"@[^\\s]+": '<usernameremoved>'}, inplace=True, regex=True)

# %% [markdown]
# # remove duplicates - Quizas esto debieramos no hacerlo. Deben haber bots que publican lo mismo

# %%
df.drop_duplicates(['text'],keep='first', inplace=True)

# %%
# numero de usuarios
tweets_by_user_data = df.groupby('user.screen_name').agg('size').sort_values(ascending=False).reset_index()
len(tweets_by_user_data)
# Out:
# 965

# %% [markdown]
# # remove digits, puntuaactions, symbols

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
punctuation+='¡¿'

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~¡¿'

# %%
#Remove digits and puntuaction
remove_digits = str.maketrans(digits, ' '*len(digits))#remove_digits = str.maketrans('', '', digits)
remove_punctuation = str.maketrans(punctuation, ' '*len(punctuation))#remove_punctuation = str.maketrans('', '', punctuation)
remove_hashtags_caracter = str.maketrans('#', ' '*len('#'))
#las palabras de los hashtag se mantiene, pero no el simbolo.

# %%
import unidecode

data = []
for tweet in df['text']:
    tweet = tweet.translate(remove_digits)
    #tweet = tweet.lower() it wasn't a good idea,, we lost a lot of
    tweet = tweet.translate(remove_punctuation)
    tweet = tweet.translate(remove_hashtags_caracter)
    tweet = tweet.lower()
    tweet = unidecode.unidecode(tweet)
    #tweet = tweet.strip().split()
    #filtered_words = [word for word in tweet if word not in stopWords]
    #corpus[id_tweet]= filtered_words
    #id_tweet+=1
    data.append(tweet)

# %% [markdown]
# # Twitter tokenizer

# %%
from nltk.tokenize import TweetTokenizer

# %%
tknzr = TweetTokenizer()
def sent_to_words(sentences):
    for sentence in sentences:
        yield(tknzr.tokenize(sentence))

# %%
data_words = list(sent_to_words(data))

# %% [markdown]
# # Create bigram and trigram models

# %%
# Build the bigram and trigram models
#quizas el min count es muy bajo
#documentaicon de bigramas 
#https://www.machinelearningplus.com/nlp/topic-modeling-gensim-python/#3importpackages
min_count = int(len(df)*0.02)
bigram = gensim.models.Phrases(data_words, min_count=min_count, threshold=1) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], min_count =min_count, threshold=1)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# See trigram example
print(trigram_mod[bigram_mod[data_words[1]]])
# Out:
# ['el', 'toquedequeda', 'hoy', 'comienza', 'a', 'las', 'y', 'termina', 'a', 'las', 'de', 'manana', 'habla', 'el', 'jefe', 'nacional', 'de', 'defensa']

# %%
# See trigram example
#print(trigram_mod[bigram_mod[data_words[1]]])
for i in range(0,5):
    print(trigram_mod[bigram_mod[data_words[i]]])
# Out:
# ['chileresiste', 'linkremoved', 'con', 'mi', 'madre', 'la', 'cante', 'gritando', 'adios', 'general', 'espero', 'con', 'mis', 'hijos', 'cantarla', 'gritando', 'adios', 'sebastian', 'toquedequeda']
# ['el', 'toquedequeda', 'hoy', 'comienza', 'a', 'las', 'y', 'termina', 'a', 'las', 'de', 'manana', 'habla', 'el', 'jefe', 'nacional', 'de', 'defensa']
# ['usernameremoved', 'calcinados', 'ni', 'que', 'hijueputas', 'en_chile', 'estan', 'matando', 'la_gente', 'las', 'milicias', 'linkremoved']
# ['plaza', 'nunoa', 'chileprotests', 'chiledespierta', 'chiledespertoan', 'linkremoved']
# ['octubre', 'el', 'mes', 'que', 'cambio', 'el', 'pais', 'chiledesperto']

# %% [markdown]
# # Remove stopwords, make bigrams and lemmatize

# %%
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

# %%
def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
# Remove Stop Words
data_words_nostops = remove_stopwords(data_words)

# %%
# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

# %%
# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# !python -m spacy download es
# Out:
# Requirement already satisfied: es_core_news_sm==2.2.0 from https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-2.2.0/es_core_news_sm-2.2.0.tar.gz#egg=es_core_news_sm==2.2.0 in c:\users\thena\tweet-pyldavis\ldavisdev\lib\site-packages (2.2.0)
# Requirement already satisfied: spacy>=2.2.0 in c:\users\thena\tweet-pyldavis\ldavisdev\lib\site-packages (from es_core_news_sm==2.2.0) (2.2.1)
# Requirement already satisfied: srsly<1.1.0,>=0.1.0 in c:\users\thena\tweet-pyldavis\ldavisdev\lib\site-packages (from spacy>=2.2.0->es_core_news_sm==2.2.0) (0.1.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.2.0 in c:\users\thena\tweet-pyldavis\ldavisdev\lib\site-packages (from spacy>=2.2.0->es_core_news_sm==2.2.0) (0.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\thena\tweet-pyldavis\ldavisdev\lib\site-packages (from spacy>=2.2.0->es_core_news_sm==2.2.0) (2.0.2)
# Requirement already satisfied: thinc<7.2.0,>=7.1.1 in c:\users\thena\tweet-pyldavis\ldavisdev\lib\site-packages (from spacy>=2.2.0->es_core_news_sm==2.2.0) (7.1.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\thena\tweet-pyldavis\ldavisdev\lib\site-packages (from spacy>=2.2.0->es_core_news_sm==2.2.0) (2.22.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\thena\tweet-pyldavis\ldavisdev\lib\site-packages (from spacy>=2.2.0->es_core_news_sm==2.2.0) (1.17.3)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in c:\users\thena\tweet-pyldavis\ldavisdev\lib\site-packages (from spacy>=2.2.0->es_core_news_sm==2.2.0) (0.4.1)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in c:\users\thena\tweet-pyldavis\ldavisdev\lib\site-packages (from spacy>=2.2.0->es_core_news_sm==2.2.0) (0.9.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\thena\tweet-pyldavis\ldavisdev\lib\site-packages (from spacy>=2.2.0->es_core_news_sm==2.2.0) (1.0.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\thena\tweet-pyldavis\ldavisdev\lib\site-packages (from spacy>=2.2.0->es_core_news_sm==2.2.0) (3.0.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in c:\users\thena\tweet-pyldavis\ldavisdev\lib\site-packages (from thinc<7.2.0,>=7.1.1->spacy>=2.2.0->es_core_news_sm==2.2.0) (4.36.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\thena\tweet-pyldavis\ldavisdev\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->es_core_news_sm==2.2.0) (1.25.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\thena\tweet-pyldavis\ldavisdev\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->es_core_news_sm==2.2.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thena\tweet-pyldavis\ldavisdev\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->es_core_news_sm==2.2.0) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\thena\tweet-pyldavis\ldavisdev\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->es_core_news_sm==2.2.0) (2.8)
# [+] Download and installation successful
# You can now load the model via spacy.load('es_core_news_sm')
# symbolic link created for C:\Users\thena\Tweet-PyLDAvis\ldavisdev\lib\site-packages\spacy\data\es <<===>> C:\Users\thena\Tweet-PyLDAvis\ldavisdev\lib\site-packages\es_core_news_sm
# [+] Linking successful
# C:\Users\thena\Tweet-PyLDAvis\ldavisdev\lib\site-packages\es_core_news_sm -->
# C:\Users\thena\Tweet-PyLDAvis\ldavisdev\lib\site-packages\spacy\data\es
# You can now load the model via spacy.load('es')

# %%
nlp = spacy.load('es', disable=['parser', 'ner'])

# %%
#sera mejor ocupar wordnetlemattizer?
# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

print(data_lemmatized[:1])
# Out:
# [['cantar', 'gritar', 'adios', 'general', 'esperar', 'hijo', 'cantarla', 'gritar', 'adios', 'toquedequeda']]

# %% [markdown]
# # Create dictionary and corpus for topic modeling

# %%
#The two main inputs to the LDA topic model are the dictionary(id2word) and the corpus
# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# View
print(corpus[:1])
# Out:
# [[(0, 2), (1, 1), (2, 1), (3, 1), (4, 1), (5, 2), (6, 1), (7, 1)]]

# %%
[[(id2word[id], freq) for id, freq in cp] for cp in corpus[:1]]
# Out:
# [[('adios', 2),
#   ('cantar', 1),
#   ('cantarla', 1),
#   ('esperar', 1),
#   ('general', 1),
#   ('gritar', 2),
#   ('hijo', 1),
#   ('toquedequeda', 1)]]

# %% [markdown]
# # Calcular mejor numero de topicos

# %%
from gensim.test.utils import common_corpus, common_dictionary

# %%
from gensim.models.wrappers import LdaMallet

# %%
import os
os.environ.update({'MALLET_HOME':r'C:\mallet'}) #OJO!, por alguna razon mallet solo puede estar disponible en esa carpeta

# %%
path_to_mallet_binary = "C:\\mallet\\bin\\mallet"

# %% [markdown]
# # Build LDA Mallet Model

# %%
num_topic = 2

# %%
start = time.time()


ldamallet = LdaMallet(path_to_mallet_binary, corpus=corpus, num_topics=num_topic, id2word=id2word)

end = time.time()
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
# Out:
# 00:00:34.11

# %%
# Show Topics
#pprint(ldamallet.show_topics(formatted=False, num_topics=num_topics))
pprint(ldamallet.show_topics(num_topics=num_topic, num_words=10, log=False, formatted=True))
# Out:
# [(0,
#   '0.094*"chiledesperto" + 0.022*"poblar" + 0.019*"gente" + '
#   '0.017*"chilesecanso" + 0.015*"decir" + 0.012*"pinera" + 0.012*"milicos" + '
#   '0.011*"renunciapinera" + 0.010*"pasar" + 0.009*"paco"'),
#  (1,
#   '0.080*"toquedequeda" + 0.022*"hacer" + 0.014*"querer" + 0.014*"estan" + '
#   '0.013*"ver" + 0.012*"militar" + 0.012*"dar" + 0.012*"solo" + '
#   '0.011*"chileno" + 0.009*"protestar"')]

# %%
# Compute Coherence Score
coherence_model_ldamallet = CoherenceModel(model=ldamallet, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_ldamallet = coherence_model_ldamallet.get_coherence()
print('\nCoherence Score: ', coherence_ldamallet)
# Out:
# Coherence Score:  0.283263753371645

# %% [markdown]
# # Mapear text con clean text

# %%
df.head(1)
# Out:
#                    id_str                      created_at user.screen_name  \
# 6488  1185817718446006272  Sun Oct 20 07:19:10 +0000 2019  NSotoCancino
#
#                   user.location  retweeted_status.created_at  \
# 6488  ÜT: -33.486316,-70.542755 NaN
#
#                                                                                                                                                  text
# 6488  #ChileResiste <linkremoved> con mi madre la cante gritando Adios general! espero con mis hijos cantarla gritando Adios Sebastian! #toquedequeda

# %%
data[0]
# Out:
# ' chileresiste  linkremoved  con mi madre la cante gritando adios general  espero con mis hijos cantarla gritando adios sebastian   toquedequeda'

# %%
df["clean_text"] = data

# %%
df.head()
# Out:
#                      id_str                      created_at user.screen_name  \
# 6488    1185817718446006272  Sun Oct 20 07:19:10 +0000 2019  NSotoCancino
# 79357   1186356278777581568  Mon Oct 21 18:59:12 +0000 2019  LauSolorzano
# 60272   1185778907435454464  Sun Oct 20 04:44:56 +0000 2019  Andrey_Lemieux
# 36652   1185972283338383367  Sun Oct 20 17:33:21 +0000 2019  Daltrian2
# 111481  1186653832895455235  Tue Oct 22 14:41:35 +0000 2019  flaviodiazbrion
#
#                     user.location  retweeted_status.created_at  \
# 6488    ÜT: -33.486316,-70.542755 NaN
# 79357   No sé.                    NaN
# 60272   NaN                       NaN
# 36652   NaN                       NaN
# 111481  Maipú, Chile              NaN
#
#                                                                                                                                                    text  \
# 6488    #ChileResiste <linkremoved> con mi madre la cante gritando Adios general! espero con mis hijos cantarla gritando Adios Sebastian! #toquedequeda
# 79357   El #ToqueDeQueda hoy comienza a las 20:00 y termina a las 6:00 de mañana. Habla el Jefe Nacional de Defensa.
# 60272   <usernameremoved> Calcinados  ni que hijueputas En Chile están matando la gente las milicias <linkremoved>
# 36652   Plaza Ñuñoa #ChileProtests #ChileDespierta #ChileDespertoً <linkremoved>
# 111481  #Octubre el mes que cambió el país.\n\n#ChileDesperto
#
#                                                                                                                                              clean_text
# 6488     chileresiste  linkremoved  con mi madre la cante gritando adios general  espero con mis hijos cantarla gritando adios sebastian   toquedequeda
# 79357   el  toquedequeda hoy comienza a las       y termina a las      de manana  habla el jefe nacional de defensa
# 60272    usernameremoved  calcinados  ni que hijueputas en chile estan matando la gente las milicias  linkremoved
# 36652   plaza nunoa  chileprotests  chiledespierta  chiledespertoan  linkremoved
# 111481   octubre el mes que cambio el pais \n\n chiledesperto

# %% [markdown]
# # Highest topic per tweet

# %%
def format_topics_sentences(ldamodel=ldamallet, corpus=corpus, texts=data):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=ldamallet, corpus=corpus, texts=data)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']

# Show
df_dominant_topic.head(20)
# Out:
#     Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0   0            0.0             0.5167
# 1   1            1.0             0.5010
# 2   2            1.0             0.5185
# 3   3            0.0             0.5000
# 4   4            0.0             0.5000
# 5   5            0.0             0.5000
# 6   6            0.0             0.5000
# 7   7            1.0             0.5290
# 8   8            0.0             0.5345
# 9   9            1.0             0.5357
# 10  10           0.0             0.5000
# 11  11           1.0             0.5273
# 12  12           1.0             0.5283
# 13  13           1.0             0.5098
# 14  14           0.0             0.5098
# 15  15           1.0             0.5295
# 16  16           0.0             0.5079
# 17  17           0.0             0.5094
# 18  18           1.0             0.5357
# 19  19           0.0             0.5185
#
#                                                                                            Keywords  \
# 0   chiledesperto, poblar, gente, chilesecanso, decir, pinera, milicos, renunciapinera, pasar, paco
# 1   toquedequeda, hacer, querer, estan, ver, militar, dar, solo, chileno, protestar
# 2   toquedequeda, hacer, querer, estan, ver, militar, dar, solo, chileno, protestar
# 3   chiledesperto, poblar, gente, chilesecanso, decir, pinera, milicos, renunciapinera, pasar, paco
# 4   chiledesperto, poblar, gente, chilesecanso, decir, pinera, milicos, renunciapinera, pasar, paco
# 5   chiledesperto, poblar, gente, chilesecanso, decir, pinera, milicos, renunciapinera, pasar, paco
# 6   chiledesperto, poblar, gente, chilesecanso, decir, pinera, milicos, renunciapinera, pasar, paco
# 7   toquedequeda, hacer, querer, estan, ver, militar, dar, solo, chileno, protestar
# 8   chiledesperto, poblar, gente, chilesecanso, decir, pinera, milicos, renunciapinera, pasar, paco
# 9   toquedequeda, hacer, querer, estan, ver, militar, dar, solo, chileno, protestar
# 10  chiledesperto, poblar, gente, chilesecanso, decir, pinera, milicos, renunciapinera, pasar, paco
# 11  toquedequeda, hacer, querer, estan, ver, militar, dar, solo, chileno, protestar
# 12  toquedequeda, hacer, querer, estan, ver, militar, dar, solo, chileno, protestar
# 13  toquedequeda, hacer, querer, estan, ver, militar, dar, solo, chileno, protestar
# 14  chiledesperto, poblar, gente, chilesecanso, decir, pinera, milicos, renunciapinera, pasar, paco
# 15  toquedequeda, hacer, querer, estan, ver, militar, dar, solo, chileno, protestar
# 16  chiledesperto, poblar, gente, chilesecanso, decir, pinera, milicos, renunciapinera, pasar, paco
# 17  chiledesperto, poblar, gente, chilesecanso, decir, pinera, milicos, renunciapinera, pasar, paco
# 18  toquedequeda, hacer, querer, estan, ver, militar, dar, solo, chileno, protestar
# 19  chiledesperto, poblar, gente, chilesecanso, decir, pinera, milicos, renunciapinera, pasar, paco
#
#                                                                                                                                                                                                                                                                                                                  Text
# 0    chileresiste  linkremoved  con mi madre la cante gritando adios general  espero con mis hijos cantarla gritando adios sebastian   toquedequeda
# 1   el  toquedequeda hoy comienza a las       y termina a las      de manana  habla el jefe nacional de defensa
# 2    usernameremoved  calcinados  ni que hijueputas en chile estan matando la gente las milicias  linkremoved
# 3   plaza nunoa  chileprotests  chiledespierta  chiledespertoan  linkremoved
# 4    octubre el mes que cambio el pais \n\n chiledesperto
# 5   yo solo quiero un chile  justo  equitativo para todos y donde se pueda dialogar de forma civilizada y democratica  fuerapinera  chiledesperto  nuevaconstitucion  nomasmilicos  fueraestadodeexcepcion
# 6    usernameremoved  estas matando tu gente  chileenresistencia  pinerarenuncia  pinerarepresor  onucomplice
# 7    usernameremoved   chiledesperto  usernameremoved   usernameremoved   y asi ha pasado muchas veces los otros dias  pero al llegar la represion policial  el  oponente  del pueblo se generan los disturbios  a tenido que ser el propio pueblo el encargado de defender lo que la policia y milicia no ha logrado
# 8   en conce  hoy nuevamente hay toque de queda  de    de la noche a las   de la manana  toquedequeda
# 9   primera noticia que veo de un baleado  que verguenza los canales de television en mi pais  que falta de etica   chileenresistencia
# 10  si se esta cortando el agua y el toque de queda es el a las       y no hay nada de comercio como vamos a ir a trabajar manana   no entiendo a protestar no mas no nos queda otra      otra vez se estan equivocando  chilesecanso  chiledesperto
# 11  hasta los mas pirulos estan protestando  grande cuico
# 12  que hombrecitos  disparando por la espalda
# 13  con los ninos no cobardes de mierda   toquedequedaahora
# 14  hermoso
# 15   y el dano que le han hecho toda la clase politica al legislar como las pelotas no cuenta \nque asuman todos  que el problema no viene de hace una semana  lleva demasiado tiempo
# 16  imaginen como seran las manifestaciones  cuando quiten el  toquedequeda y sigan haciendose los weones sin dar soluciones claras  el lunes no esta lejos   urgente  chiledespierto
# 17  chiledesperta \n chilesecaso\n toquedequeda\n chile\n nosonsololos  pesos  linkremoved
# 18   chiledesperto  chilesecanso \n\ncolegio farmeceutico da aviso para las ciudades   cualquier persona que requiera adquirir sus medicamentos urgente y no sabe que farmacia esta abierta hoy domingo  pueden escribirnos a comunicaciones usernameremoved
# 19  awwwwww\ntan buenitos    \n\nhubo que dejar la zorra en el pais para que soltaran la teta wn ohh \n renunciapinera  chileenresistencia\n chileprotests

# %% [markdown]
# #  Find the most representative tweets for each topic

# %%
# Group top 5 sentences under each topic
numero_de_tweets_por_topico = 10


sent_topics_sorteddf_mallet = pd.DataFrame()
sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic') # esta matriz contiene todos los tweets con el porcentaje de contribucion y max topico. se agrupa y se obtiene lo q queremos

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, 
                                             grp.sort_values(['Perc_Contribution'], ascending=False).head(numero_de_tweets_por_topico)], 
                                            axis=0)


# Reset Index    
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Text"]

# Show
sent_topics_sorteddf_mallet
# Out:
#     Topic_Num  Topic_Perc_Contrib  \
# 0   0.0        0.5781
# 1   0.0        0.5705
# 2   0.0        0.5692
# 3   0.0        0.5692
# 4   0.0        0.5627
# 5   0.0        0.5593
# 6   0.0        0.5572
# 7   0.0        0.5571
# 8   0.0        0.5556
# 9   0.0        0.5538
# 10  1.0        0.5892
# 11  1.0        0.5863
# 12  1.0        0.5846
# 13  1.0        0.5846
# 14  1.0        0.5822
# 15  1.0        0.5821
# 16  1.0        0.5781
# 17  1.0        0.5767
# 18  1.0        0.5758
# 19  1.0        0.5714
#
#                                                                                            Keywords  \
# 0   chiledesperto, poblar, gente, chilesecanso, decir, pinera, milicos, renunciapinera, pasar, paco
# 1   chiledesperto, poblar, gente, chilesecanso, decir, pinera, milicos, renunciapinera, pasar, paco
# 2   chiledesperto, poblar, gente, chilesecanso, decir, pinera, milicos, renunciapinera, pasar, paco
# 3   chiledesperto, poblar, gente, chilesecanso, decir, pinera, milicos, renunciapinera, pasar, paco
# 4   chiledesperto, poblar, gente, chilesecanso, decir, pinera, milicos, renunciapinera, pasar, paco
# 5   chiledesperto, poblar, gente, chilesecanso, decir, pinera, milicos, renunciapinera, pasar, paco
# 6   chiledesperto, poblar, gente, chilesecanso, decir, pinera, milicos, renunciapinera, pasar, paco
# 7   chiledesperto, poblar, gente, chilesecanso, decir, pinera, milicos, renunciapinera, pasar, paco
# 8   chiledesperto, poblar, gente, chilesecanso, decir, pinera, milicos, renunciapinera, pasar, paco
# 9   chiledesperto, poblar, gente, chilesecanso, decir, pinera, milicos, renunciapinera, pasar, paco
# 10  toquedequeda, hacer, querer, estan, ver, militar, dar, solo, chileno, protestar
# 11  toquedequeda, hacer, querer, estan, ver, militar, dar, solo, chileno, protestar
# 12  toquedequeda, hacer, querer, estan, ver, militar, dar, solo, chileno, protestar
# 13  toquedequeda, hacer, querer, estan, ver, militar, dar, solo, chileno, protestar
# 14  toquedequeda, hacer, querer, estan, ver, militar, dar, solo, chileno, protestar
# 15  toquedequeda, hacer, querer, estan, ver, militar, dar, solo, chileno, protestar
# 16  toquedequeda, hacer, querer, estan, ver, militar, dar, solo, chileno, protestar
# 17  toquedequeda, hacer, querer, estan, ver, militar, dar, solo, chileno, protestar
# 18  toquedequeda, hacer, querer, estan, ver, militar, dar, solo, chileno, protestar
# 19  toquedequeda, hacer, querer, estan, ver, militar, dar, solo, chileno, protestar
#
#                                                                                                                                                                                                                                                                                                             Text
# 0   este tipo no comprende la diferencia entre caridad y solidaridad  menos entiende la relacion de esta ultima con topicos de justicia social \n\ndeberia leer esta excelente columna del periodista  usernameremoved  \n\n linkremoved
# 1    latelemiente  latelemiente  latelemiente  latelemiente  latelemiente  latelemiente  latelemiente  latelemiente \n\nrt gente    esto no puede quedar asi    los medios estan tapando todo  \n\n chileenresistencia \n chileprotesta \n chileselevanta\n chilesecanso
# 2   el pueblo chileno honesto y trabajador prevalecera  despues de la tomenta el frente amplio y partido comunista deberan pagar su traicion contra el pueblo chileno   \n chalecosamarillos\n chilesecanso \n toquedequeda
# 3   iturriaga se tuvo que bajar los pantalones   por su dicho de esta manana  se entendio como una suerte de disculpas aclarar dicho de que  es un hombre feliz  que el no esta en guerra   toque de queda en rm decretado a partir de las      hrs   chiledesperto  nohayvueltaatras  linkremoved
# 4   deberian dejar que el mundo sea gobernado por comunistas de izquierda    asi terminan de volver mierda el mundo y no tendriamos que esperar ningun meteorito
# 5   eres una verdadera verguenza  usernameremoved  sigues y sigues con el mismo discurso no tienes nada concreto  renuniciapinera  chiledespertoan   chileenresistencia  renunciapinera esto seguira porque nadie te cree y ya no tienes el respeto del pueblo  linkremoved
# 6   ya tenemos victimas producto de tener milicos y pacos violentos  seguramente jalados  en la calle \nel gobierno   usernameremoved  y el resto de los charlatanes que hablan de orden y seguridad publica  se iran a pronunciar sobre este tipo de violencia \n chiledesperto  linkremoved
# 7   prensa culia  saqueo saqueo destrozos buses quemados saqueo\n\nredes sociales  milicos disparando contra la gente en valpo  pacos entrando a casas en maipu  montajes creados por los pacos\n\ntele culia manipuladora y asquerosa \n\n toquedequeda
# 8    chiledesperto  las autopistas urbanas aumentaron sus valores un     extra al ipc y las ganancias desde que fueron creadas    minimo que despues de esto bajen el precio en un        \ncobros extremadamente abusivos     linkremoved
# 9   esto esperaban los pseudo revolucionarios y despues preguntan porque mandan a los milicos [?][?][?][?] smh  y no me vengan que son los pacos y bla bla  esto fue el pueblo  robando y aprovechando cualquier cosa para actuar con violencia      toquedequeda  chiledesperto  linkremoved
# 10  ellos nunca desearon la democracia  solo buscaban un espacio para sus negocios y no asustar a los inversionistas extranjeros \ncuando vieron obstaculos  volvieron a ser quienes realmente son  chileresiste  toquedequeda  valparaiso  despiertachile  linkremoved
# 11  es increible que existan proyectos que llevan anos en el congreso y esto lo aprueben en un par de horas  al fin empezaron a hacer su pega politicos basura  \n\n chilesecanso  toquedequedachile  toquedequeda  chile  santiago  fueramilicos
# 12  sra  usernameremoved  existen personas despreciables  pero una mujer abyecta como usted  pocas  su apice de conciencia yace sobre pilas de crimenes horrendos contra la humanidad  hablo sobre dizque  expectativas   pamplinas  su gestion es un insulto a la filantropia
# 13   usernameremoved   usernameremoved  no me matan a nadie  los mios estan bien cuidados en casa  y tienes razon los carabineros no siempre llegan cuando los llamas  pero tampoco son el mal encarnado  urgente  toquedequeda
# 14  dia   que hago yo para ayudar empatia humildad converse durante de   horas con decenas de vecinos esperando mi turno en el super con muchos pensamos distinto pero llegamos a la misma conclusion  chiledesperto no populismo abusos  promesas  quieren paz y cuidar la democracia
# 15  jose arrieta con tobalaba  intento de saqueo en pleno cacerolazo y las personas lo frustramos  militares llegaron con disparo al aire sin saber y sin acercarse a la gente a preguntar que sucedia  por suerte se dieron cuenta   penalolen  toquedequeda
# 16  sabe cual es  realmente el desencontento de la gente  es q los politicos le den la espalda  es ver como ellos tienen los privilegios la burguesia q la clase mas humilde no puede tener  y hoy  usernameremoved   usernameremoved   usernameremoved  le dieron las espalda a
# 17  cobertura especial  estadoemergencia\n\nen  mesacentral comienza el  ratpack  con  usernameremoved   usernameremoved  y  usernameremoved  conversamos de la reunion en la moneda  los proximos dias en el gobierno y la busqueda de una salida institucional a la crisis \n\n>[?] linkremoved   linkremoved
# 18  han matado a destajo y a todos les importa mas que esten saqueando un supermercado a que le esten quitando la vida a cientos de personas    que rabia que impotencia su falta de empatia    toquedequeda  toquequeda  laprensamiente  renunciapineractm  linkremoved
# 19  ya se vio el poder de la delincuencia  ahora falta ver la mano dura q debe poner el gobierno  todos estos delincuentes que han destruido el pais  son en su mayoria personas q han gozado de la puerta giratoria  si no se endurecen las penas terminaremos como venezuela  toquedequeda

# %%
sent_topics_sorteddf_mallet.head()
# Out:
#    Topic_Num  Topic_Perc_Contrib  \
# 0  0.0        0.5781
# 1  0.0        0.5705
# 2  0.0        0.5692
# 3  0.0        0.5692
# 4  0.0        0.5627
#
#                                                                                           Keywords  \
# 0  chiledesperto, poblar, gente, chilesecanso, decir, pinera, milicos, renunciapinera, pasar, paco
# 1  chiledesperto, poblar, gente, chilesecanso, decir, pinera, milicos, renunciapinera, pasar, paco
# 2  chiledesperto, poblar, gente, chilesecanso, decir, pinera, milicos, renunciapinera, pasar, paco
# 3  chiledesperto, poblar, gente, chilesecanso, decir, pinera, milicos, renunciapinera, pasar, paco
# 4  chiledesperto, poblar, gente, chilesecanso, decir, pinera, milicos, renunciapinera, pasar, paco
#
#                                                                                                                                                                                                                                                                                               Text
# 0  este tipo no comprende la diferencia entre caridad y solidaridad  menos entiende la relacion de esta ultima con topicos de justicia social \n\ndeberia leer esta excelente columna del periodista  usernameremoved  \n\n linkremoved
# 1   latelemiente  latelemiente  latelemiente  latelemiente  latelemiente  latelemiente  latelemiente  latelemiente \n\nrt gente    esto no puede quedar asi    los medios estan tapando todo  \n\n chileenresistencia \n chileprotesta \n chileselevanta\n chilesecanso
# 2  el pueblo chileno honesto y trabajador prevalecera  despues de la tomenta el frente amplio y partido comunista deberan pagar su traicion contra el pueblo chileno   \n chalecosamarillos\n chilesecanso \n toquedequeda
# 3  iturriaga se tuvo que bajar los pantalones   por su dicho de esta manana  se entendio como una suerte de disculpas aclarar dicho de que  es un hombre feliz  que el no esta en guerra   toque de queda en rm decretado a partir de las      hrs   chiledesperto  nohayvueltaatras  linkremoved
# 4  deberian dejar que el mundo sea gobernado por comunistas de izquierda    asi terminan de volver mierda el mundo y no tendriamos que esperar ningun meteorito

# %%
sent_topics_sorteddf_mallet.rename(columns={"Text": "clean_text"},inplace=True)

# %% [markdown]
# # find original text - username- created at

# %%
sent_topics_sorteddf_mallet = pd.merge(sent_topics_sorteddf_mallet, df, on='clean_text', how='left')

# %%
from datetime import datetime

# %%
sent_topics_sorteddf_mallet.to_csv("Topic_Modeling_num_topics_"+str(num_topic)+"_"+datetime.now().strftime("%Y_%m_%d_%H_%M")+".csv")

# %% [markdown]
# # Topic distribution across documents

# %%
# Number of Documents for Each Topic
topic_counts = df_topic_sents_keywords['Dominant_Topic'].value_counts()

# Percentage of Documents for Each Topic
topic_contribution = round(topic_counts/topic_counts.sum(), 4)

# Topic Number and Keywords
topic_num_keywords = df_topic_sents_keywords[['Dominant_Topic', 'Topic_Keywords']]

# Concatenate Column wise
df_dominant_topics = pd.concat([topic_num_keywords.drop_duplicates(subset='Dominant_Topic', keep='first').sort_values(by=['Dominant_Topic']).reset_index(drop=True), topic_counts.sort_index(), topic_contribution.sort_index()], axis=1)

# Change Column names
df_dominant_topics.columns = ['Dominant_Topic', 'Topic_Keywords', 'Num_Documents', 'Perc_Documents']

# %%
#funciona perfecto
df_dominant_topics
# Out:
#      Dominant_Topic  \
# 0.0  0.0
# 1.0  1.0
#
#                                                                                       Topic_Keywords  \
# 0.0  chiledesperto, poblar, gente, chilesecanso, decir, pinera, milicos, renunciapinera, pasar, paco
# 1.0  toquedequeda, hacer, querer, estan, ver, militar, dar, solo, chileno, protestar
#
#      Num_Documents  Perc_Documents
# 0.0  595            0.595
# 1.0  405            0.405

# %% [markdown]
# # Visualize topics with Mallet

# %%
prueba = gensim.models.wrappers.ldamallet.malletmodel2ldamodel(ldamallet)

# %%
pyLDAvis.enable_notebook()

# %%
data = pyLDAvis.gensim.prepare(prueba, corpus,id2word, mds='pcoa')
# Out:
# c:\users\thena\tweet-pyldavis\pyldavis\Twitter_pyLDAvis\_prepare.py:234: RuntimeWarning: divide by zero encountered in log
#   kernel = (topic_given_term * np.log((topic_given_term.T / topic_proportion).T))
# c:\users\thena\tweet-pyldavis\pyldavis\Twitter_pyLDAvis\_prepare.py:253: RuntimeWarning: divide by zero encountered in log
#   log_lift = np.log(topic_term_dists / term_proportion)
# c:\users\thena\tweet-pyldavis\pyldavis\Twitter_pyLDAvis\_prepare.py:254: RuntimeWarning: divide by zero encountered in log
#   log_ttd = np.log(topic_term_dists)

# %%
type(data)
# Out:
# Twitter_pyLDAvis._prepare.PreparedData

# %%
#data.to_
pyLDAvis.save_html(data, "Topic_Modeling_num_topics_"+str(num_topic)+"_"+datetime.now().strftime("%Y_%m_%d_%H_%M")+".html")

# %%
data
# Out:
# PreparedData(topic_coordinates=              x    y  topics  cluster       Freq
# topic
# 1      0.331725  0.0  1       1        50.102271
# 0     -0.331725  0.0  2       1        49.897729, topic_info=    Category        Freq           Term       Total  loglift  logprob
# 19   Default  319.000000  chiledesperto  319.000000  30.0000  30.0000
# 7    Default  271.000000  toquedequeda   271.000000  29.0000  29.0000
# 76   Default  76.000000   hacer          76.000000   28.0000  28.0000
# 40   Default  74.000000   poblar         74.000000   27.0000  27.0000
# 15   Default  64.000000   gente          64.000000   26.0000  26.0000
# ..       ...        ...     ...                ...       ...      ...
# 211  Topic2   15.002525   igual          15.002525   0.6952  -5.4179
# 3    Topic2   15.002525   esperar        15.002525   0.6952  -5.4179
# 442  Topic2   15.002525   saquear        15.002525   0.6952  -5.4179
# 522  Topic2   20.003367   derecho        24.009775   0.5126  -5.1302
# 555  Topic2   17.002862   coser          19.006066   0.5838  -5.2927
#
# [155 rows x 6 columns], token_table=      Topic      Freq       Term
# term
# 760   2      0.999832  abalanzar
# 803   2      0.999832  absoluto
# 123   1      0.998401  abuso
# 811   2      0.999832  ademar
# 277   1      0.998401  ahora
# ...  ..           ...     ...
# 54    1      0.998401  ver
# 824   2      0.999832  vestir
# 43    1      0.998401  vez
# 122   1      0.998401  vivir
# 691   1      0.998401  volver
#
# [127 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 1])

# %% [markdown]
# # Obtener tweets

# %%
#df[df['texto_completo'].str.contains("carpathy")]['texto_completo']
